# %% [markdown]
# # SQL Sales Analysis for Northwind Traders
#
# **Created By:** Reese Oliver <br>
# **Date:** December 4 2024 <br>
#
# ## Introduction
#
# In this SQL Data Analysis project, we will explore sales data from *Northwind Traders*, an international gourmet food distributor. By exploring sales patterns and performance trends, we’ll uncover key insights that will equip management to make powerful, data-driven decisions that will accelerate business growth and sharpen competitive edge.
#
# The core business questions we'll aim to answer include:
#
# 1. <u>Profit margin analysis</u>: to **highlight the most profitable products**, as well as **pricing inefficiencies**.
# 2. <u>Product lifecycle analysis</u>: to **identify products reaching the end of their lifecycle** or when new products are gaining traction.
# 3. <u>Employee performance evaluation</u>: to **optimize productivity and team effectiveness**.
# 4. <u>Product and category performance analysis</u>: to **improve inventory management and marketing strategies**.
# 5. <u>Customer purchase behavior analysis</u>: to help **target high-value customers** with personalized promotions.
#
#
# In more technical terms, we'll calculate running totals, compute averages, rank items, and analyze growth rates. These skills are fundamental for extracting valuable business insights.

# %% [markdown]
# ### Installing PostgreSQL and Downloading the Northwind Database
#
# [**Click this link**](https://www.dataquest.io/blog/install-postgresql-14-7-for-macos/?_gl=1*hxnc77*_gcl_au*MjA3NjIwMDMzNi4xNzMzMTYxMTgw*_ga*MTcyOTQyNjcxNC4xNzMzMTYxMTgw*_ga_YXMFSKC6DP*MTczMzM1MzEzNi41LjEuMTczMzM1MzI5My42MC4wLjIxMzA4MjU3Ng..) to access a guide that will help you install PostgreSQL on your computer. After you install PostgreSQL, this guide will walk you through downloading the Northwind Traders database and show you how to connect to the database with PostgreSQL.

# %% [markdown]
# ### Connecting Jupyter Notebook to PostgreSQL

# %% [markdown]
# Run `!pip install ipython-sql` in your notebook or terminal window to install the `ipython-sql` package, which enables you to write SQL queries directly in your Jupyter Notebook, making it easier to execute and visualize the results of your queries within the notebook environment.

# %%
# Loads the sql extension for ipython
# %load_ext sql

# %% [markdown]
# This magic command loads the SQL extension for ipython. By loading this extension, you can use the SQL magic commands, such as `%sql` and `%%sql`, to run SQL queries directly in the Jupyter Notebook cells. <br>
#
# **Keep in mind:**
# 1. For **single line queries**, use `%sql`
# 2. For **multiple-line queries**, use `%%sql`

# %%
# Establishes a connection to the Northwind database using the PostgreSQL database system.
# %sql postgresql://postgres@localhost:5432/northwind

# %%
# %%sql
# -- # Get overview of database schema
# SELECT table_name AS name,
#        table_type AS type
#   FROM information_schema.tables
#  WHERE table_schema = 'public' AND table_type in ('BASE TABLE', 'VIEW');
# Out:
#  * postgresql://postgres@localhost:5432/northwind
# 14 rows affected.
# [('orders', 'BASE TABLE'),
#  ('employees', 'BASE TABLE'),
#  ('shippers', 'BASE TABLE'),
#  ('products', 'BASE TABLE'),
#  ('region', 'BASE TABLE'),
#  ('territories', 'BASE TABLE'),
#  ('customer_customer_demo', 'BASE TABLE'),
#  ('customer_demographics', 'BASE TABLE'),
#  ('customers', 'BASE TABLE'),
#  ('categories', 'BASE TABLE'),
#  ('employee_territories', 'BASE TABLE'),
#  ('order_details', 'BASE TABLE'),
#  ('us_states', 'BASE TABLE'),
#  ('suppliers', 'BASE TABLE')]

# %% [markdown]
# ##### *A Note for Jupyter Notebook Users*

# %% [markdown]
# The employee table contains a column named `photo` that cannot be rendered because of its data type. The photo column isn't necessary for this project, so run this command in your notebook to remove the column:
# `%sql ALTER TABLE employees DROP COLUMN photo;`

# %% [markdown]
# ### Exploring the Data

# %%
# %%sql
# -- # Join the customers and orders table to get more detailed information about each order
# SELECT *
#   FROM customers AS c
#   JOIN orders AS o
#     ON c.customer_id = o.customer_id
#  LIMIT 3;
# Out:
#  * postgresql://postgres@localhost:5432/northwind
# 3 rows affected.
# [('VINET', 'Vins et alcools Chevalier', 'Paul Henriot', 'Accounting Manager', "59 rue de l'Abbaye", 'Reims', None, '51100', 'France', '26.47.15.10', '26.47.15.11', 10248, 'VINET', 5, datetime.date(1996, 7, 4), datetime.date(1996, 8, 1), datetime.date(1996, 7, 16), 3, 32.38, 'Vins et alcools Chevalier', "59 rue de l'Abbaye", 'Reims', None, '51100', 'France'),
#  ('TOMSP', 'Toms Spezialitäten', 'Karin Josephs', 'Marketing Manager', 'Luisenstr. 48', 'Münster', None, '44087', 'Germany', '0251-031259', '0251-035695', 10249, 'TOMSP', 6, datetime.date(1996, 7, 5), datetime.date(1996, 8, 16), datetime.date(1996, 7, 10), 1, 11.61, 'Toms Spezialitäten', 'Luisenstr. 48', 'Münster', None, '44087', 'Germany'),
#  ('HANAR', 'Hanari Carnes', 'Mario Pontes', 'Accounting Manager', 'Rua do Paço, 67', 'Rio de Janeiro', 'RJ', '05454-876', 'Brazil', '(21) 555-0091', '(21) 555-8765', 10250, 'HANAR', 4, datetime.date(1996, 7, 8), datetime.date(1996, 8, 5), datetime.date(1996, 7, 12), 2, 65.83, 'Hanari Carnes', 'Rua do Paço, 67', 'Rio de Janeiro', 'RJ', '05454-876', 'Brazil')]

# %%
# %%sql
# -- # Combine order_details, products, and orders tables to get detailed order information, including the product name and quantity.
# SELECT *
#   FROM orders AS o
#   JOIN order_details AS od ON o.order_id = od.order_id
#   JOIN products AS p on od.product_id = p.product_id
#  LIMIT 3;
# Out:
#  * postgresql://postgres@localhost:5432/northwind
# 3 rows affected.
# [(10248, 'VINET', 5, datetime.date(1996, 7, 4), datetime.date(1996, 8, 1), datetime.date(1996, 7, 16), 3, 32.38, 'Vins et alcools Chevalier', "59 rue de l'Abbaye", 'Reims', None, '51100', 'France', 10248, 11, 14.0, 12, 0.0, 11, 'Queso Cabrales', 5, 4, '1 kg pkg.', 21.0, 22, 30, 30, 0),
#  (10248, 'VINET', 5, datetime.date(1996, 7, 4), datetime.date(1996, 8, 1), datetime.date(1996, 7, 16), 3, 32.38, 'Vins et alcools Chevalier', "59 rue de l'Abbaye", 'Reims', None, '51100', 'France', 10248, 42, 9.8, 10, 0.0, 42, 'Singaporean Hokkien Fried Mee', 20, 5, '32 - 1 kg pkgs.', 14.0, 26, 0, 0, 1),
#  (10248, 'VINET', 5, datetime.date(1996, 7, 4), datetime.date(1996, 8, 1), datetime.date(1996, 7, 16), 3, 32.38, 'Vins et alcools Chevalier', "59 rue de l'Abbaye", 'Reims', None, '51100', 'France', 10248, 72, 34.8, 5, 0.0, 72, 'Mozzarella di Giovanni', 14, 4, '24 - 200 g pkgs.', 34.8, 14, 0, 0, 0)]

# %%
# %%sql
# -- # Combine employees and orders tables to see who is responsible for each order.
# SELECT e.first_name, e.last_name, e.title, e.hire_date, o.*
#   FROM employees AS e
#   JOIN orders AS o ON e.employee_id = o.employee_id
#  LIMIT 3;
# Out:
#  * postgresql://postgres@localhost:5432/northwind
# 3 rows affected.
# [('Steven', 'Buchanan', 'Sales Manager', datetime.date(1993, 10, 17), 10248, 'VINET', 5, datetime.date(1996, 7, 4), datetime.date(1996, 8, 1), datetime.date(1996, 7, 16), 3, 32.38, 'Vins et alcools Chevalier', "59 rue de l'Abbaye", 'Reims', None, '51100', 'France'),
#  ('Michael', 'Suyama', 'Sales Representative', datetime.date(1993, 10, 17), 10249, 'TOMSP', 6, datetime.date(1996, 7, 5), datetime.date(1996, 8, 16), datetime.date(1996, 7, 10), 1, 11.61, 'Toms Spezialitäten', 'Luisenstr. 48', 'Münster', None, '44087', 'Germany'),
#  ('Margaret', 'Peacock', 'Sales Representative', datetime.date(1993, 5, 3), 10250, 'HANAR', 4, datetime.date(1996, 7, 8), datetime.date(1996, 8, 5), datetime.date(1996, 7, 12), 2, 65.83, 'Hanari Carnes', 'Rua do Paço, 67', 'Rio de Janeiro', 'RJ', '05454-876', 'Brazil')]

# %% [markdown]
# Now that we've done some preliminary data exploration, we can go ahead and start analyzing the company database for valuable insights.

# %% [markdown]
# ## Profit Margin Analysis
#
# **Profit margin analysis (PMA)** (often considered the holy grail of business health) is crucial for management because it provides a clear and actionable understanding of how efficiently the company is generating profit relative to its sales.
#
# PMA helps management identify which products are the most profitable and which are underperforming. **This allows the company to focus resources on high-margin products and adjust strategies for low-margin items (such as price increases, cost reductions, or even discontinuation).**
#
# For example, if certain products are generating low profit margins despite high sales volume, it may signal the need for a price increase or a reevaluation of the pricing strategy. Conversely, if the profit margin is high, it may be an opportunity to slightly lower prices to boost sales volume without significantly affecting profitability.
#
# $$
# \text{Profit Margin} = \frac{\text{Profit}}{\text{Revenue}}
# $$

# %%
# %%sql
# -- # Calculate profit margin, assuming a 30% markup on standard product price
# WITH revenues_and_costs AS (
#   SELECT o.order_id,
#          p.product_name,
#          p.product_id,
#          od.quantity,
#          od.unit_price AS sales_price,
#          p.unit_price AS standard_price,
#
#          -- # Estimated cost based on 30% markup
#          (p.unit_price / 1.30) AS estimated_cost,
#
#          -- # Total revenue
#          ((od.quantity * od.unit_price) - od.discount) AS total_revenue,
#
#          -- # Total estimated cost
#          (od.quantity * (p.unit_price / 1.30)) AS total_estimated_cost
#   FROM orders o
#   JOIN order_details od ON o.order_id = od.order_id
#   JOIN products p ON od.product_id = p.product_id
# ),
#
# -- # Calculate profit and margin
# profit_margins AS (
#   SELECT order_id,
#          product_name,
#          product_id,
#          quantity,
#          total_revenue,
#          total_estimated_cost,
#          (total_revenue - total_estimated_cost) AS total_profit,
#          (total_revenue - total_estimated_cost) / total_revenue AS profit_margin
#     FROM revenues_and_costs
# )
#
# SELECT pm.order_id,
#        pm.product_name,
#        pm.quantity,
#        pm.total_estimated_cost,
#        pm.total_revenue,
#        pm.total_profit,
#        ROUND(pm.profit_margin::NUMERIC, 4) AS profit_margin
# FROM profit_margins pm
# ORDER BY pm.profit_margin DESC;
# Out:
#  * postgresql://postgres@localhost:5432/northwind
# 2155 rows affected.
# [(10657, 'Genen Shouyu', 50, 500.0, 775.0, 275.0, Decimal('0.3548')),
#  (10579, 'Genen Shouyu', 10, 100.0, 155.0, 55.0, Decimal('0.3548')),
#  (10592, 'Genen Shouyu', 25, 250.0, 387.44999999925494, 137.44999999925494, Decimal('0.3548')),
#  (10500, 'Genen Shouyu', 12, 120.0, 185.94999999925494, 65.94999999925494, Decimal('0.3547')),
#  (10935, 'Chai', 21, 290.7692307692307, 378.0, 87.23076923076928, Decimal('0.2308')),
#  (11031, 'Guaraná Fantástica', 21, 72.69230769230768, 94.5, 21.80769230769232, Decimal('0.2308')),
#  (10720, 'Steeleye Stout', 21, 290.7692307692307, 378.0, 87.23076923076928, Decimal('0.2308')),
#  (10827, 'Chartreuse verte', 21, 290.7692307692307, 378.0, 87.23076923076928, Decimal('0.2308')),
#  (10621, 'Flotemysost', 15, 248.07692307692304, 322.5, 74.42307692307696, Decimal('0.2308')),
#  (11002, 'Pâté chinois', 40, 738.4615384615383, 960.0, 221.53846153846166, Decimal('0.2308')),
#  (10746, 'Singaporean Hokkien Fried Mee', 28, 301.5384615384615, 392.0, 90.46153846153851, Decimal('0.2308')),
#  (10914, 'Flotemysost', 25, 413.4615384615384, 537.5, 124.0384615384616, Decimal('0.2308')),
#  (10926, 'Konbu', 10, 46.153846153846146, 60.0, 13.846153846153854, Decimal('0.2308')),
#  (10940, 'Konbu', 20, 92.30769230769229, 120.0, 27.692307692307708, Decimal('0.2308')),
#  (10945, 'Konbu', 20, 92.30769230769229, 120.0, 27.692307692307708, Decimal('0.2308')),
#  (10956, "Sir Rodney's Scones", 12, 92.30769230769229, 120.0, 27.692307692307708, Decimal('0.2308')),
#  (10626, 'Flotemysost', 20, 330.7692307692307, 430.0, 99.23076923076928, Decimal('0.2308')),
#  (10615, 'Pâté chinois', 5, 92.30769230769229, 120.0, 27.692307692307708, Decimal('0.2308')),
#  (10609, "Sir Rodney's Scones", 6, 46.153846153846146, 60.0, 13.846153846153854, Decimal('0.2308')),
#  (11058, "Sir Rodney's Scones", 3, 23.076923076923073, 30.0, 6.923076923076927, Decimal('0.2308')),
#  (10723, 'Gumbär Gummibärchen', 15, 360.34614856426526, 468.4499931335449, 108.10384456927966, Decimal('0.2308')),
#  (10713, 'Gumbär Gummibärchen', 30, 720.6922971285305, 936.8999862670898, 216.20768913855932, Decimal('0.2308')),
#  (11038, 'Flotemysost', 30, 496.1538461538461, 645.0, 148.84615384615392, Decimal('0.2308')),
#  (10544, 'Laughing Lumberjack Lager', 7, 75.38461538461537, 98.0, 22.615384615384627, Decimal('0.2308')),
#  (10539, 'Maxilaku', 6, 92.30769230769229, 120.0, 27.692307692307708, Decimal('0.2308')),
#  (10526, 'Konbu', 10, 46.153846153846146, 60.0, 13.846153846153854, Decimal('0.2308')),
#  (10522, 'Northwoods Cranberry Sauce', 24, 738.4615384615383, 960.0, 221.53846153846166, Decimal('0.2308')),
#  (10508, 'Konbu', 10, 46.153846153846146, 60.0, 13.846153846153854, Decimal('0.2308')),
#  (11031, 'Konbu', 80, 369.23076923076917, 480.0, 110.76923076923083, Decimal('0.2308')),
#  (11031, 'Chai', 45, 623.076923076923, 810.0, 186.92307692307702, Decimal('0.2308')),
#  (10504, "Sir Rodney's Scones", 12, 92.30769230769229, 120.0, 27.692307692307708, Decimal('0.2308')),
#  (11024, 'Flotemysost', 50, 826.9230769230768, 1075.0, 248.0769230769232, Decimal('0.2308')),
#  (10702, 'Aniseed Syrup', 6, 46.153846153846146, 60.0, 13.846153846153854, Decimal('0.2308')),
#  (10688, 'Sasquatch Ale', 14, 150.76923076923075, 196.0, 45.230769230769255, Decimal('0.2308')),
#  (10829, 'Konbu', 10, 46.153846153846146, 60.0, 13.846153846153854, Decimal('0.2308')),
#  (10686, 'Gumbär Gummibärchen', 15, 360.34614856426526, 468.4499931335449, 108.10384456927966, Decimal('0.2308')),
#  (10715, 'Flotemysost', 30, 496.1538461538461, 645.0, 148.84615384615392, Decimal('0.2308')),
#  (11011, 'Flotemysost', 20, 330.7692307692307, 430.0, 99.23076923076928, Decimal('0.2308')),
#  (10895, 'Chartreuse verte', 45, 623.076923076923, 810.0, 186.92307692307702, Decimal('0.2308')),
#  (10898, 'Konbu', 5, 23.076923076923073, 30.0, 6.923076923076927, Decimal('0.2308')),
#  (11007, 'Singaporean Hokkien Fried Mee', 14, 150.76923076923075, 196.0, 45.230769230769255, Decimal('0.2308')),
#  (10901, 'Flotemysost', 30, 496.1538461538461, 645.0, 148.84615384615392, Decimal('0.2308')),
#  (10903, 'Konbu', 40, 184.61538461538458, 240.0, 55.384615384615415, Decimal('0.2308')),
#  (10620, 'Filo Mix', 5, 26.92307692307692, 35.0, 8.07692307692308, Decimal('0.2308')),
#  (10619, "Sir Rodney's Scones", 42, 323.07692307692304, 420.0, 96.92307692307696, Decimal('0.2308')),
#  (10836, 'Steeleye Stout', 6, 83.07692307692307, 108.0, 24.923076923076934, Decimal('0.2308')),
#  (10611, 'Chai', 6, 83.07692307692307, 108.0, 24.923076923076934, Decimal('0.2308')),
#  (10852, 'Tarte au sucre', 50, 1896.1538168100208, 2464.9999618530273, 568.8461450430066, Decimal('0.2308')),
#  (10609, 'Chai', 3, 41.53846153846153, 54.0, 12.461538461538467, Decimal('0.2308')),
#  (11058, 'Camembert Pierrot', 21, 549.2307692307692, 714.0, 164.76923076923083, Decimal('0.2308')),
#  (10853, 'Carnarvon Tigers', 10, 480.7692307692307, 625.0, 144.23076923076928, Decimal('0.2308')),
#  (10607, 'Boston Crab Meat', 42, 594.4615261371318, 772.7999839782715, 178.33845784113964, Decimal('0.2308')),
#  (10607, 'Geitost', 14, 26.92307692307692, 35.0, 8.07692307692308, Decimal('0.2308')),
#  (11056, 'Pâté chinois', 35, 646.1538461538461, 840.0, 193.84615384615392, Decimal('0.2308')),
#  (10607, "Uncle Bob's Organic Dried Pears", 45, 1038.4615384615383, 1350.0, 311.53846153846166, Decimal('0.2308')),
#  (10599, 'Tarte au sucre', 10, 379.23076336200415, 492.99999237060547, 113.76922900860131, Decimal('0.2308')),
#  (10751, 'Nord-Ost Matjeshering', 30, 597.4615243765023, 776.6999816894531, 179.2384573129508, Decimal('0.2308')),
#  (11055, 'NuNuCa Nuß-Nougat-Creme', 15, 161.53846153846152, 210.0, 48.46153846153848, Decimal('0.2308')),
#  (10752, 'Gudbrandsdalsost', 3, 83.07692307692307, 108.0, 24.923076923076934, Decimal('0.2308')),
#  (11054, 'Laughing Lumberjack Lager', 20, 215.38461538461536, 280.0, 64.61538461538464, Decimal('0.2308')),
#  (10911, 'Laughing Lumberjack Lager', 15, 161.53846153846152, 210.0, 48.46153846153848, Decimal('0.2308')),
#  (10591, 'Aniseed Syrup', 14, 107.69230769230768, 140.0, 32.30769230769232, Decimal('0.2308')),
#  (10650, 'Nord-Ost Matjeshering', 30, 597.4615243765023, 776.6999816894531, 179.2384573129508, Decimal('0.2308')),
#  (11003, 'Boston Crab Meat', 10, 141.538458604079, 183.99999618530273, 42.46153758122372, Decimal('0.2308')),
#  (10574, 'Tarte au sucre', 10, 379.23076336200415, 492.99999237060547, 113.76922900860131, Decimal('0.2308')),
#  (10574, 'Geitost', 14, 26.92307692307692, 35.0, 8.07692307692308, Decimal('0.2308')),
#  (10718, 'Tarte au sucre', 20, 758.4615267240083, 985.9999847412109, 227.53845801720263, Decimal('0.2308')),
#  (10573, 'Perth Pasties', 25, 630.7692160973181, 819.9999809265137, 189.23076482919555, Decimal('0.2308')),
#  (10573, 'Sasquatch Ale', 40, 430.7692307692307, 560.0, 129.23076923076928, Decimal('0.2308')),
#  (10757, 'Sasquatch Ale', 30, 323.07692307692304, 420.0, 96.92307692307696, Decimal('0.2308')),
#  (10567, 'Manjimup Dried Apples', 3, 122.30769230769229, 159.0, 36.69230769230771, Decimal('0.2308')),
#  (11045, 'Manjimup Dried Apples', 24, 978.4615384615383, 1272.0, 293.53846153846166, Decimal('0.2308')),
#  (11015, 'Nord-Ost Matjeshering', 15, 298.73076218825116, 388.34999084472656, 89.6192286564754, Decimal('0.2308')),
#  (10757, 'Tarte au sucre', 30, 1137.6922900860125, 1478.9999771118164, 341.30768702580394, Decimal('0.2308')),
#  (10560, 'Nord-Ost Matjeshering', 20, 398.3076829176682, 517.7999877929688, 119.49230487530053, Decimal('0.2308')),
#  (10558, 'Filo Mix', 30, 161.53846153846152, 210.0, 48.46153846153848, Decimal('0.2308')),
#  (11042, 'Gula Malacca', 15, 224.42308572622443, 291.7500114440918, 67.32692571786737, Decimal('0.2308')),
#  (10758, 'Filo Mix', 60, 323.07692307692304, 420.0, 96.92307692307696, Decimal('0.2308')),
#  (10553, 'Steeleye Stout', 6, 83.07692307692307, 108.0, 24.923076923076934, Decimal('0.2308')),
#  (10553, 'Pavlova', 14, 187.92308513934793, 244.30001068115234, 56.37692554180441, Decimal('0.2308')),
#  (10552, 'Gudbrandsdalsost', 18, 498.4615384615384, 648.0, 149.5384615384616, Decimal('0.2308')),
#  (10856, 'Singaporean Hokkien Fried Mee', 20, 215.38461538461536, 280.0, 64.61538461538464, Decimal('0.2308')),
#  (11039, 'Steeleye Stout', 24, 332.30769230769226, 432.0, 99.69230769230774, Decimal('0.2308')),
#  (10550, 'Teatime Chocolate Biscuits', 10, 70.7692293020395, 91.99999809265137, 21.23076879061186, Decimal('0.2308')),
#  (10860, 'Manjimup Dried Apples', 3, 122.30769230769229, 159.0, 36.69230769230771, Decimal('0.2308')),
#  (10710, 'Teatime Chocolate Biscuits', 5, 35.38461465101975, 45.999999046325684, 10.61538439530593, Decimal('0.2308')),
#  (10546, 'Tarte au sucre', 40, 1516.9230534480166, 1971.9999694824219, 455.07691603440526, Decimal('0.2308')),
#  (10861, 'Carnarvon Tigers', 20, 961.5384615384614, 1250.0, 288.46153846153857, Decimal('0.2308')),
#  (10671, 'Tarte au sucre', 10, 379.23076336200415, 492.99999237060547, 113.76922900860131, Decimal('0.2308')),
#  (10537, 'Manjimup Dried Apples', 6, 244.61538461538458, 318.0, 73.38461538461542, Decimal('0.2308')),
#  (11035, 'Singaporean Hokkien Fried Mee', 30, 323.07692307692304, 420.0, 96.92307692307696, Decimal('0.2308')),
#  (10534, 'Nord-Ost Matjeshering', 10, 199.1538414588341, 258.8999938964844, 59.74615243765027, Decimal('0.2308')),
#  (10532, 'Louisiana Hot Spiced Okra', 24, 313.8461538461538, 408.0, 94.15384615384619, Decimal('0.2308')),
#  (10532, 'Nord-Ost Matjeshering', 15, 298.73076218825116, 388.34999084472656, 89.6192286564754, Decimal('0.2308')),
#  (10720, 'Flotemysost', 8, 132.3076923076923, 172.0, 39.69230769230771, Decimal('0.2308')),
#  (10864, 'Laughing Lumberjack Lager', 15, 161.53846153846152, 210.0, 48.46153846153848, Decimal('0.2308')),
#  (10524, 'Nord-Ost Matjeshering', 10, 199.1538414588341, 258.8999938964844, 59.74615243765027, Decimal('0.2308')),
#  (10870, 'Steeleye Stout', 3, 41.53846153846153, 54.0, 12.461538461538467, Decimal('0.2308')),
#  (10521, 'Steeleye Stout', 3, 41.53846153846153, 54.0, 12.461538461538467, Decimal('0.2308')),
#  (10516, 'Singaporean Hokkien Fried Mee', 20, 215.38461538461536, 280.0, 64.61538461538464, Decimal('0.2308')),
#  (11031, 'Flotemysost', 16, 264.6153846153846, 344.0, 79.38461538461542, Decimal('0.2308')),
#  (10885, 'Guaraná Fantástica', 12, 41.53846153846153, 54.0, 12.461538461538467, Decimal('0.2308')),
#  (11003, 'Filo Mix', 10, 53.84615384615384, 70.0, 16.15384615384616, Decimal('0.2308')),
#  (10887, 'NuNuCa Nuß-Nougat-Creme', 5, 53.84615384615384, 70.0, 16.15384615384616, Decimal('0.2308')),
#  (10728, 'Nord-Ost Matjeshering', 15, 298.73076218825116, 388.34999084472656, 89.6192286564754, Decimal('0.2308')),
#  (10889, 'Côte de Blaye', 40, 8107.692307692307, 10540.0, 2432.3076923076933, Decimal('0.2308')),
#  (10502, 'Laughing Lumberjack Lager', 30, 323.07692307692304, 420.0, 96.92307692307696, Decimal('0.2308')),
#  (10652, 'Singaporean Hokkien Fried Mee', 20, 215.38461538461536, 280.0, 64.61538461538464, Decimal('0.2308')),
#  (10498, 'Singaporean Hokkien Fried Mee', 30, 323.07692307692304, 420.0, 96.92307692307696, Decimal('0.2308')),
#  (10498, 'Boston Crab Meat', 5, 70.7692293020395, 91.99999809265137, 21.23076879061186, Decimal('0.2308')),
#  (10769, 'Tarte au sucre', 15, 568.8461450430062, 739.4999885559082, 170.65384351290197, Decimal('0.2308')),
#  (10771, 'Flotemysost', 16, 264.6153846153846, 344.0, 79.38461538461542, Decimal('0.2308')),
#  (11028, 'Pâté chinois', 35, 646.1538461538461, 840.0, 193.84615384615392, Decimal('0.2308')),
#  (10779, 'Tarte au sucre', 20, 758.4615267240083, 985.9999847412109, 227.53845801720263, Decimal('0.2308')),
#  (10783, 'Côte de Blaye', 5, 1013.4615384615383, 1317.5, 304.03846153846166, Decimal('0.2308')),
#  (10704, 'Chocolade', 24, 235.38461538461536, 306.0, 70.61538461538464, Decimal('0.2308')),
#  (10890, 'Sasquatch Ale', 10, 107.69230769230768, 140.0, 32.30769230769232, Decimal('0.2308')),
#  (10789, 'Carnarvon Tigers', 30, 1442.3076923076922, 1875.0, 432.69230769230785, Decimal('0.2308')),
#  (10893, 'Thüringer Rostbratwurst', 24, 2285.353863055889, 2970.9600219726562, 685.6061589167671, Decimal('0.2308')),
#  (10696, 'Spegesild', 18, 166.15384615384613, 216.0, 49.84615384615387, Decimal('0.2308')),
#  (10795, 'Pavlova', 65, 872.5000381469725, 1134.2500495910645, 261.7500114440919, Decimal('0.2308')),
#  (10805, 'Sasquatch Ale', 10, 107.69230769230768, 140.0, 32.30769230769232, Decimal('0.2308')),
#  (10805, 'Côte de Blaye', 10, 2026.9230769230767, 2635.0, 608.0769230769233, Decimal('0.2308')),
#  (10694, "Uncle Bob's Organic Dried Pears", 90, 2076.9230769230767, 2700.0, 623.0769230769233, Decimal('0.2308')),
#  (10809, 'Filo Mix', 20, 107.69230769230768, 140.0, 32.30769230769232, Decimal('0.2308')),
#  (10810, 'NuNuCa Nuß-Nougat-Creme', 5, 53.84615384615384, 70.0, 16.15384615384616, Decimal('0.2308')),
#  (10811, 'Tunnbröd', 18, 124.6153846153846, 162.0, 37.3846153846154, Decimal('0.2308')),
#  (10813, 'Spegesild', 35, 323.07692307692304, 420.0, 96.92307692307696, Decimal('0.2308')),
#  (10821, 'Manjimup Dried Apples', 6, 244.61538461538458, 318.0, 73.38461538461542, Decimal('0.2308')),
#  (10734, 'Nord-Ost Matjeshering', 15, 298.73076218825116, 388.34999084472656, 89.6192286564754, Decimal('0.2308')),
#  (10895, 'Guaraná Fantástica', 110, 380.7692307692307, 495.0, 114.23076923076928, Decimal('0.2308')),
#  (11004, 'Lakkalikööri', 6, 83.07692307692307, 108.0, 24.923076923076934, Decimal('0.2308')),
#  (10919, 'Boston Crab Meat', 20, 283.076917208158, 367.99999237060547, 84.92307516244745, Decimal('0.2308')),
#  (11018, 'Carnarvon Tigers', 10, 480.7692307692307, 625.0, 144.23076923076928, Decimal('0.2308')),
#  (10927, 'Filo Mix', 5, 26.92307692307692, 35.0, 8.07692307692308, Decimal('0.2308')),
#  (10636, 'Escargots de Bourgogne', 6, 61.153846153846146, 79.5, 18.346153846153854, Decimal('0.2308')),
#  (10937, 'Sasquatch Ale', 20, 215.38461538461536, 280.0, 64.61538461538464, Decimal('0.2308')),
#  (11009, 'Guaraná Fantástica', 12, 41.53846153846153, 54.0, 12.461538461538467, Decimal('0.2308')),
#  (10942, 'Maxilaku', 28, 430.7692307692307, 560.0, 129.23076923076928, Decimal('0.2308')),
#  (10998, 'Guaraná Fantástica', 12, 41.53846153846153, 54.0, 12.461538461538467, Decimal('0.2308')),
#  (10829, 'Camembert Pierrot', 21, 549.2307692307692, 714.0, 164.76923076923083, Decimal('0.2308')),
#  (10996, 'Singaporean Hokkien Fried Mee', 40, 430.7692307692307, 560.0, 129.23076923076928, Decimal('0.2308')),
#  (10949, 'Tarte au sucre', 60, 2275.384580172025, 2957.999954223633, 682.6153740516079, Decimal('0.2308')),
#  (11008, 'Flotemysost', 21, 347.30769230769226, 451.5, 104.19230769230774, Decimal('0.2308')),
#  (10957, 'Nord-Ost Matjeshering', 30, 597.4615243765023, 776.6999816894531, 179.2384573129508, Decimal('0.2308')),
#  (10962, "Uncle Bob's Organic Dried Pears", 45, 1038.4615384615383, 1350.0, 311.53846153846166, Decimal('0.2308')),
#  (10962, 'Gudbrandsdalsost', 9, 249.2307692307692, 324.0, 74.7692307692308, Decimal('0.2308')),
#  (10964, 'Côte de Blaye', 5, 1013.4615384615383, 1317.5, 304.03846153846166, Decimal('0.2308')),
#  (10969, 'Spegesild', 9, 83.07692307692307, 108.0, 24.923076923076934, Decimal('0.2308')),
#  (10972, 'Geitost', 7, 13.46153846153846, 17.5, 4.03846153846154, Decimal('0.2308')),
#  (10978, 'Boston Crab Meat', 10, 141.538458604079, 183.99999618530273, 42.46153758122372, Decimal('0.2308')),
#  (10990, "Sir Rodney's Scones", 65, 499.99999999999994, 650.0, 150.00000000000006, Decimal('0.2308')),
#  (10627, 'Tarte au sucre', 15, 568.8461450430062, 739.4999885559082, 170.65384351290197, Decimal('0.2308')),
#  (11066, 'Teatime Chocolate Biscuits', 42, 297.2307630685659, 386.39999198913574, 89.16922892056982, Decimal('0.2308')),
#  (10684, 'Boston Crab Meat', 20, 283.076917208158, 367.99999237060547, 84.92307516244745, Decimal('0.2308')),
#  (10625, 'Singaporean Hokkien Fried Mee', 5, 53.84615384615384, 70.0, 16.15384615384616, Decimal('0.2308')),
#  (10625, 'Tofu', 3, 53.653846153846146, 69.75, 16.096153846153854, Decimal('0.2308')),
#  (10624, 'Thüringer Rostbratwurst', 6, 571.3384657639723, 742.7400054931641, 171.40153972919177, Decimal('0.2308')),
#  (10623, 'Guaraná Fantástica', 3, 10.384615384615383, 13.5, 3.1153846153846168, Decimal('0.2308')),
#  (10748, 'Boston Crab Meat', 40, 566.153834416316, 735.9999847412109, 169.8461503248949, Decimal('0.2308')),
#  (10645, 'Carnarvon Tigers', 20, 961.5384615384614, 1250.0, 288.46153846153857, Decimal('0.2308')),
#  (11063, 'Sasquatch Ale', 30, 323.07692307692304, 420.0, 96.92307692307696, Decimal('0.2308')),
#  (10621, 'Teatime Chocolate Biscuits', 5, 35.38461465101975, 45.999999046325684, 10.61538439530593, Decimal('0.2308')),
#  (10670, 'Tunnbröd', 32, 221.53846153846152, 288.0, 66.46153846153848, Decimal('0.2308')),
#  (10728, 'Pâté chinois', 12, 221.53846153846152, 288.0, 66.46153846153848, Decimal('0.2308')),
#  (11077, 'Pâté chinois', 2, 36.92307692307692, 48.0, 11.07692307692308, Decimal('0.2308')),
#  (11077, 'Filo Mix', 2, 10.769230769230768, 14.0, 3.2307692307692317, Decimal('0.2308')),
#  (11077, 'Mascarpone Fabioli', 1, 24.615384615384613, 32.0, 7.384615384615387, Decimal('0.2308')),
#  (11077, 'Tunnbröd', 2, 13.846153846153845, 18.0, 4.153846153846155, Decimal('0.2308')),
#  (11077, 'Konbu', 4, 18.46153846153846, 24.0, 5.53846153846154, Decimal('0.2308')),
#  (11077, 'Aniseed Syrup', 4, 30.769230769230766, 40.0, 9.230769230769234, Decimal('0.2308')),
#  (11070, 'Gorgonzola Telino', 20, 192.3076923076923, 250.0, 57.69230769230771, Decimal('0.2308')),
#  (11053, 'Mascarpone Fabioli', 20, 492.30769230769226, 640.0, 147.69230769230774, Decimal('0.2308')),
#  (11048, 'Scottish Longbreads', 42, 403.8461538461538, 525.0, 121.15384615384619, Decimal('0.2308')),
#  (11045, 'Geitost', 15, 28.846153846153843, 37.5, 8.653846153846157, Decimal('0.2308')),
#  (11039, 'Maxilaku', 60, 923.076923076923, 1200.0, 276.923076923077, Decimal('0.2308')),
#  (11038, 'Filo Mix', 2, 10.769230769230768, 14.0, 3.2307692307692317, Decimal('0.2308')),
#  (11034, 'Gula Malacca', 12, 179.53846858097955, 233.40000915527344, 53.86154057429388, Decimal('0.2308')),
#  (11026, 'Carnarvon Tigers', 8, 384.6153846153846, 500.0, 115.38461538461542, Decimal('0.2308')),
#  (11024, 'Geitost', 30, 57.692307692307686, 75.0, 17.307692307692314, Decimal('0.2308')),
#  (11024, 'Gumbär Gummibärchen', 12, 288.27691885141223, 374.75999450683594, 86.4830756554237, Decimal('0.2308')),
#  (11022, 'Teatime Chocolate Biscuits', 35, 247.69230255713828, 321.9999933242798, 74.30769076714151, Decimal('0.2308')),
#  (11019, 'Maxilaku', 2, 30.769230769230766, 40.0, 9.230769230769234, Decimal('0.2308')),
#  (11019, 'Spegesild', 3, 27.69230769230769, 36.0, 8.30769230769231, Decimal('0.2308')),
#  (11017, 'Raclette Courdavault', 110, 4653.846153846153, 6050.0, 1396.1538461538466, Decimal('0.2308')),
#  (11017, 'Aniseed Syrup', 25, 192.3076923076923, 250.0, 57.69230769230771, Decimal('0.2308')),
#  (11013, 'Singaporean Hokkien Fried Mee', 4, 43.07692307692307, 56.0, 12.923076923076927, Decimal('0.2308')),
#  (11007, 'Northwoods Cranberry Sauce', 30, 923.076923076923, 1200.0, 276.923076923077, Decimal('0.2308')),
#  (11006, 'Chai', 8, 110.76923076923076, 144.0, 33.23076923076924, Decimal('0.2308')),
#  (11005, 'Chai', 2, 27.69230769230769, 36.0, 8.30769230769231, Decimal('0.2308')),
#  (11004, 'Gumbär Gummibärchen', 6, 144.13845942570612, 187.37999725341797, 43.24153782771185, Decimal('0.2308')),
#  (11003, 'Chai', 4, 55.38461538461538, 72.0, 16.61538461538462, Decimal('0.2308')),
#  (11001, 'Pâté chinois', 6, 110.76923076923076, 144.0, 33.23076923076924, Decimal('0.2308')),
#  (11001, 'Spegesild', 25, 230.76923076923075, 300.0, 69.23076923076925, Decimal('0.2308')),
#  (11001, "Gustaf's Knäckebröd", 25, 403.8461538461538, 525.0, 121.15384615384619, Decimal('0.2308')),
#  (10989, "Grandma's Boysenberry Spread", 40, 769.2307692307692, 1000.0, 230.76923076923083, Decimal('0.2308')),
#  (10977, 'Vegie-spread', 20, 675.3846388596754, 878.0000305175781, 202.6153916579027, Decimal('0.2308')),
#  (10975, 'Northwoods Cranberry Sauce', 16, 492.30769230769226, 640.0, 147.69230769230774, Decimal('0.2308')),
#  (10974, 'Vegie-spread', 10, 337.6923194298377, 439.00001525878906, 101.30769582895135, Decimal('0.2308')),
#  (10973, 'Gumbär Gummibärchen', 5, 120.1153828547551, 156.14999771118164, 36.03461485642654, Decimal('0.2308')),
#  (10971, 'Thüringer Rostbratwurst', 14, 1333.123086782602, 1733.0600128173828, 399.93692603478075, Decimal('0.2308')),
#  (10962, 'Lakkalikööri', 44, 609.2307692307692, 792.0, 182.76923076923083, Decimal('0.2308')),
#  (10962, 'Konbu', 77, 355.38461538461536, 462.0, 106.61538461538464, Decimal('0.2308')),
#  (10948, 'Pâté chinois', 4, 73.84615384615384, 96.0, 22.15384615384616, Decimal('0.2308')),
#  (10945, 'Gorgonzola Telino', 10, 96.15384615384615, 125.0, 28.846153846153854, Decimal('0.2308')),
#  (10934, "Grandma's Boysenberry Spread", 20, 384.6153846153846, 500.0, 115.38461538461542, Decimal('0.2308')),
#  (10929, "Sir Rodney's Scones", 60, 461.5384615384615, 600.0, 138.4615384615385, Decimal('0.2308')),
#  (10921, 'Vegie-spread', 40, 1350.7692777193508, 1756.0000610351562, 405.2307833158054, Decimal('0.2308')),
#  (10917, 'Nord-Ost Matjeshering', 1, 19.91538414588341, 25.889999389648438, 5.974615243765026, Decimal('0.2308')),
#  (10916, 'Mascarpone Fabioli', 6, 147.69230769230768, 192.0, 44.30769230769232, Decimal('0.2308')),
#  (10915, 'Geitost', 30, 57.692307692307686, 75.0, 17.307692307692314, Decimal('0.2308')),
#  (10909, 'Pavlova', 15, 201.34616264930136, 261.7500114440918, 60.403848794790434, Decimal('0.2308')),
#  (10903, 'Scottish Longbreads', 20, 192.3076923076923, 250.0, 57.69230769230771, Decimal('0.2308')),
#  (10893, 'Northwoods Cranberry Sauce', 30, 923.076923076923, 1200.0, 276.923076923077, Decimal('0.2308')),
#  (10883, 'Guaraná Fantástica', 8, 27.69230769230769, 36.0, 8.30769230769231, Decimal('0.2308')),
#  (10875, 'Maxilaku', 15, 230.76923076923075, 300.0, 69.23076923076925, Decimal('0.2308')),
#  (10869, 'Scottish Longbreads', 20, 192.3076923076923, 250.0, 57.69230769230771, Decimal('0.2308')),
#  (10868, 'Gumbär Gummibärchen', 20, 480.4615314190204, 624.5999908447266, 144.13845942570617, Decimal('0.2308')),
#  (10867, 'Perth Pasties', 3, 75.69230593167818, 98.39999771118164, 22.707691779503463, Decimal('0.2308')),
#  (10864, 'Steeleye Stout', 4, 55.38461538461538, 72.0, 16.61538461538462, Decimal('0.2308')),
#  (10862, 'Filo Mix', 8, 43.07692307692307, 56.0, 12.923076923076927, Decimal('0.2308')),
#  (10862, 'Queso Cabrales', 25, 403.8461538461538, 525.0, 121.15384615384619, Decimal('0.2308')),
#  (10858, 'Schoggi Schokolade', 10, 337.6923194298377, 439.00001525878906, 101.30769582895135, Decimal('0.2308')),
#  (10857, 'Aniseed Syrup', 30, 230.76923076923075, 300.0, 69.23076923076925, Decimal('0.2308')),
#  (10842, 'Scottish Longbreads', 20, 192.3076923076923, 250.0, 57.69230769230771, Decimal('0.2308')),
#  (10837, 'Konbu', 6, 27.69230769230769, 36.0, 8.30769230769231, Decimal('0.2308')),
#  (10831, 'Steeleye Stout', 8, 110.76923076923076, 144.0, 33.23076923076924, Decimal('0.2308')),
#  (10825, 'Gumbär Gummibärchen', 12, 288.27691885141223, 374.75999450683594, 86.4830756554237, Decimal('0.2308')),
#  (10818, 'Mascarpone Fabioli', 20, 492.30769230769226, 640.0, 147.69230769230774, Decimal('0.2308')),
#  (10815, 'Geitost', 16, 30.769230769230766, 40.0, 9.230769230769234, Decimal('0.2308')),
#  (10798, 'Tarte au sucre', 2, 75.84615267240083, 98.5999984741211, 22.75384580172026, Decimal('0.2308')),
#  (10796, 'Gula Malacca', 10, 149.61539048414963, 194.50000762939453, 44.8846171452449, Decimal('0.2308')),
#  (10793, 'Filo Mix', 8, 43.07692307692307, 56.0, 12.923076923076927, Decimal('0.2308')),
#  (10783, 'Gorgonzola Telino', 10, 96.15384615384615, 125.0, 28.846153846153854, Decimal('0.2308')),
#  (10779, 'Pavlova', 20, 268.4615501990685, 349.00001525878906, 80.53846505972058, Decimal('0.2308')),
#  (10499, 'Maxilaku', 25, 384.6153846153846, 500.0, 115.38461538461542, Decimal('0.2308')),
#  (10502, 'Perth Pasties', 6, 151.38461186335635, 196.79999542236328, 45.415383559006926, Decimal('0.2308')),
#  (10767, 'Singaporean Hokkien Fried Mee', 2, 21.538461538461537, 28.0, 6.4615384615384635, Decimal('0.2308')),
#  (10766, 'Scottish Longbreads', 40, 384.6153846153846, 500.0, 115.38461538461542, Decimal('0.2308')),
#  (10520, 'Guaraná Fantástica', 8, 27.69230769230769, 36.0, 8.30769230769231, Decimal('0.2308')),
#  (10529, 'Scottish Longbreads', 20, 192.3076923076923, 250.0, 57.69230769230771, Decimal('0.2308')),
#  (10762, 'Manjimup Dried Apples', 28, 1141.5384615384614, 1484.0, 342.46153846153857, Decimal('0.2308')),
#  (10762, 'Chartreuse verte', 16, 221.53846153846152, 288.0, 66.46153846153848, Decimal('0.2308')),
#  (10536, 'Gorgonzola Telino', 20, 192.3076923076923, 250.0, 57.69230769230771, Decimal('0.2308')),
#  (10536, 'Geitost', 30, 57.692307692307686, 75.0, 17.307692307692314, Decimal('0.2308')),
#  (10539, 'Konbu', 8, 36.92307692307692, 48.0, 11.07692307692308, Decimal('0.2308')),
#  (10539, "Sir Rodney's Scones", 15, 115.38461538461537, 150.0, 34.61538461538463, Decimal('0.2308')),
#  (10539, 'Geitost', 15, 28.846153846153843, 37.5, 8.653846153846157, Decimal('0.2308')),
#  (10540, 'Aniseed Syrup', 60, 461.5384615384615, 600.0, 138.4615384615385, Decimal('0.2308')),
#  (10540, 'Gumbär Gummibärchen', 40, 960.9230628380408, 1249.1999816894531, 288.27691885141235, Decimal('0.2308')),
#  (10760, 'Schoggi Schokolade', 40, 1350.7692777193508, 1756.0000610351562, 405.2307833158054, Decimal('0.2308')),
#  (10759, 'Mascarpone Fabioli', 10, 246.15384615384613, 320.0, 73.84615384615387, Decimal('0.2308')),
#  (10551, 'Gula Malacca', 40, 598.4615619365985, 778.0000305175781, 179.5384685809796, Decimal('0.2308')),
#  (10558, 'Zaanse koeken', 25, 182.69230769230768, 237.5, 54.80769230769232, Decimal('0.2308')),
#  (10758, 'Gumbär Gummibärchen', 20, 480.4615314190204, 624.5999908447266, 144.13845942570617, Decimal('0.2308')),
#  (10561, 'Gula Malacca', 10, 149.61539048414963, 194.50000762939453, 44.8846171452449, Decimal('0.2308')),
#  (10563, 'Inlagd Sill', 25, 365.38461538461536, 475.0, 109.61538461538464, Decimal('0.2308')),
#  (10757, 'Raclette Courdavault', 7, 296.15384615384613, 385.0, 88.84615384615387, Decimal('0.2308')),
#  (10576, 'Gorgonzola Telino', 20, 192.3076923076923, 250.0, 57.69230769230771, Decimal('0.2308')),
#  (10587, 'Gumbär Gummibärchen', 6, 144.13845942570612, 187.37999725341797, 43.24153782771185, Decimal('0.2308')),
#  (10589, 'Steeleye Stout', 4, 55.38461538461538, 72.0, 16.61538461538462, Decimal('0.2308')),
#  (10752, 'Chai', 8, 110.76923076923076, 144.0, 33.23076923076924, Decimal('0.2308')),
#  (10614, 'Queso Cabrales', 14, 226.15384615384613, 294.0, 67.84615384615387, Decimal('0.2308')),
#  (10614, "Sir Rodney's Scones", 8, 61.53846153846153, 80.0, 18.461538461538467, Decimal('0.2308')),
#  (10623, 'Tofu', 21, 375.57692307692304, 488.25, 112.67307692307696, Decimal('0.2308')),
#  (10624, 'Gula Malacca', 10, 149.61539048414963, 194.50000762939453, 44.8846171452449, Decimal('0.2308')),
#  (10626, 'Perth Pasties', 12, 302.7692237267127, 393.59999084472656, 90.83076711801385, Decimal('0.2308')),
#  (10748, 'Tunnbröd', 44, 304.6153846153846, 396.0, 91.38461538461542, Decimal('0.2308')),
#  (10747, 'Vegie-spread', 9, 303.92308748685394, 395.10001373291016, 91.17692624605621, Decimal('0.2308')),
#  (10639, 'Carnarvon Tigers', 8, 384.6153846153846, 500.0, 115.38461538461542, Decimal('0.2308')),
#  (10641, 'Chang', 50, 730.7692307692307, 950.0, 219.23076923076928, Decimal('0.2308')),
#  (10746, 'Konbu', 6, 27.69230769230769, 36.0, 8.30769230769231, Decimal('0.2308')),
#  (10745, 'Gula Malacca', 16, 239.3846247746394, 311.20001220703125, 71.81538743239184, Decimal('0.2308')),
#  (10657, 'Gnocchi di nonna Alice', 45, 1315.3846153846152, 1710.0, 394.61538461538476, Decimal('0.2308')),
#  (10658, "Sir Rodney's Scones", 60, 461.5384615384615, 600.0, 138.4615384615385, Decimal('0.2308')),
#  (10660, "Sir Rodney's Marmalade", 21, 1308.4615384615383, 1701.0, 392.53846153846166, Decimal('0.2308')),
#  (10662, 'Scottish Longbreads', 10, 96.15384615384615, 125.0, 28.846153846153854, Decimal('0.2308')),
#  (10671, 'Pavlova', 10, 134.23077509953424, 174.50000762939453, 40.26923252986029, Decimal('0.2308')),
#  (10737, 'Konbu', 4, 18.46153846153846, 24.0, 5.53846153846154, Decimal('0.2308')),
#  (10678, 'Queso Manchego La Pastora', 100, 2923.076923076923, 3800.0, 876.9230769230771, Decimal('0.2308')),
#  (10678, 'Geitost', 30, 57.692307692307686, 75.0, 17.307692307692314, Decimal('0.2308')),
#  (10682, 'Geitost', 30, 57.692307692307686, 75.0, 17.307692307692314, Decimal('0.2308')),
#  (10691, 'Gula Malacca', 24, 359.0769371619591, 466.8000183105469, 107.72308114858777, Decimal('0.2308')),
#  (10692, 'Vegie-spread', 20, 675.3846388596754, 878.0000305175781, 202.6153916579027, Decimal('0.2308')),
#  (10733, 'Tofu', 16, 286.15384615384613, 372.0, 85.84615384615387, Decimal('0.2308')),
#  (10705, 'Gorgonzola Telino', 20, 192.3076923076923, 250.0, 57.69230769230771, Decimal('0.2308')),
#  (10705, 'Mascarpone Fabioli', 4, 98.46153846153845, 128.0, 29.538461538461547, Decimal('0.2308')),
#  (10706, 'Pavlova', 20, 268.4615501990685, 349.00001525878906, 80.53846505972058, Decimal('0.2308')),
#  (10709, 'Manjimup Dried Apples', 28, 1141.5384615384614, 1484.0, 342.46153846153857, Decimal('0.2308')),
#  (10713, 'Spegesild', 24, 221.53846153846152, 288.0, 66.46153846153848, Decimal('0.2308')),
#  (10729, "Sir Rodney's Scones", 30, 230.76923076923075, 300.0, 69.23076923076925, Decimal('0.2308')),
#  (10716, 'Manjimup Dried Apples', 7, 285.38461538461536, 371.0, 85.61538461538464, Decimal('0.2308')),
#  (10718, 'Pavlova', 20, 268.4615501990685, 349.00001525878906, 80.53846505972058, Decimal('0.2308')),
#  (10725, 'Filo Mix', 4, 21.538461538461537, 28.0, 6.4615384615384635, Decimal('0.2308')),
#  (10725, 'Pâté chinois', 6, 110.76923076923076, 144.0, 33.23076923076924, Decimal('0.2308')),
#  (10517, 'Outback Lager', 6, 69.23076923076923, 90.0, 20.769230769230774, Decimal('0.2308')),
#  (10844, "Gustaf's Knäckebröd", 35, 565.3846153846154, 735.0, 169.61538461538464, Decimal('0.2308')),
#  (10842, 'Outback Lager', 12, 138.46153846153845, 180.0, 41.53846153846155, Decimal('0.2308')),
#  (10510, 'Thüringer Rostbratwurst', 36, 3428.030794583834, 4456.440032958984, 1028.4092383751504, Decimal('0.2308')),
#  (10508, 'Chartreuse verte', 10, 138.46153846153845, 180.0, 41.53846153846155, Decimal('0.2308')),
#  (10842, 'Queso Cabrales', 15, 242.3076923076923, 315.0, 72.69230769230771, Decimal('0.2308')),
#  (10987, "Uncle Bob's Organic Dried Pears", 60, 1384.6153846153845, 1800.0, 415.3846153846155, Decimal('0.2308')),
#  (10841, 'Raclette Courdavault', 50, 2115.3846153846152, 2750.0, 634.6153846153848, Decimal('0.2308')),
#  (10921, 'Steeleye Stout', 10, 138.46153846153845, 180.0, 41.53846153846155, Decimal('0.2308')),
#  (10768, 'Flotemysost', 12, 198.46153846153845, 258.0, 59.53846153846155, Decimal('0.2308')),
#  (10505, 'Tarte au sucre', 3, 113.76922900860126, 147.89999771118164, 34.13076870258038, Decimal('0.2308')),
#  (10503, 'Louisiana Fiery Hot Pepper Sauce', 20, 323.8461421086238, 420.99998474121094, 97.15384263258716, Decimal('0.2308')),
#  (10502, 'Rogede sild', 21, 153.46153846153845, 199.5, 46.03846153846155, Decimal('0.2308')),
#  (10772, 'Thüringer Rostbratwurst', 18, 1714.015397291917, 2228.220016479492, 514.2046191875752, Decimal('0.2308')),
#  (10772, 'Raclette Courdavault', 25, 1057.6923076923076, 1375.0, 317.3076923076924, Decimal('0.2308')),
#  (11073, 'Guaraná Fantástica', 20, 69.23076923076923, 90.0, 20.769230769230774, Decimal('0.2308')),
#  (10836, 'Wimmers gute Semmelknödel', 30, 767.3076923076923, 997.5, 230.19230769230774, Decimal('0.2308')),
#  (10774, 'Louisiana Hot Spiced Okra', 50, 653.8461538461538, 850.0, 196.1538461538462, Decimal('0.2308')),
#  (10949, 'Ikura', 30, 715.3846153846154, 930.0, 214.61538461538464, Decimal('0.2308')),
#  (10956, 'Manjimup Dried Apples', 8, 326.15384615384613, 424.0, 97.84615384615387, Decimal('0.2308')),
#  (10957, 'Steeleye Stout', 40, 553.8461538461538, 720.0, 166.1538461538462, Decimal('0.2308')),
#  (10782, 'Gorgonzola Telino', 1, 9.615384615384615, 12.5, 2.884615384615385, Decimal('0.2308')),
#  (10785, 'Ikura', 10, 238.46153846153845, 310.0, 71.53846153846155, Decimal('0.2308')),
#  (10785, 'Rhönbräu Klosterbier', 10, 59.61538461538461, 77.5, 17.884615384615387, Decimal('0.2308')),
#  (10789, 'Steeleye Stout', 15, 207.69230769230768, 270.0, 62.30769230769232, Decimal('0.2308')),
#  (10789, 'Scottish Longbreads', 18, 173.07692307692307, 225.0, 51.923076923076934, Decimal('0.2308')),
#  (10832, 'Wimmers gute Semmelknödel', 3, 76.73076923076923, 99.75, 23.019230769230774, Decimal('0.2308')),
#  (10998, 'Rhönbräu Klosterbier', 30, 178.84615384615384, 232.5, 53.65384615384616, Decimal('0.2308')),
#  (10831, 'Côte de Blaye', 8, 1621.5384615384614, 2108.0, 486.46153846153857, Decimal('0.2308')),
#  (10702, 'Lakkalikööri', 15, 207.69230769230768, 270.0, 62.30769230769232, Decimal('0.2308')),
#  (10831, 'Teatime Chocolate Biscuits', 2, 14.153845860407902, 18.399999618530273, 4.246153758122372, Decimal('0.2308')),
#  (10792, 'Tourtière', 3, 17.192307252150314, 22.34999942779541, 5.157692175645096, Decimal('0.2308')),
#  (10704, 'Guaraná Fantástica', 35, 121.15384615384615, 157.5, 36.346153846153854, Decimal('0.2308')),
#  (10988, "Uncle Bob's Organic Dried Pears", 60, 1384.6153846153845, 1800.0, 415.3846153846155, Decimal('0.2308')),
#  (10799, 'Raclette Courdavault', 25, 1057.6923076923076, 1375.0, 317.3076923076924, Decimal('0.2308')),
#  (11017, 'Outback Lager', 30, 346.15384615384613, 450.0, 103.84615384615387, Decimal('0.2308')),
#  (11022, 'Gudbrandsdalsost', 30, 830.7692307692307, 1080.0, 249.23076923076928, Decimal('0.2308')),
#  (10829, 'Northwoods Cranberry Sauce', 20, 615.3846153846154, 800.0, 184.61538461538464, Decimal('0.2308')),
#  (10807, 'Boston Crab Meat', 1, 14.153845860407902, 18.399999618530273, 4.246153758122372, Decimal('0.2308')),
#  (10828, 'Côte de Blaye', 2, 405.38461538461536, 527.0, 121.61538461538464, Decimal('0.2308')),
#  (11021, 'Mozzarella di Giovanni', 35, 936.9230563823993, 1217.9999732971191, 281.07691691471985, Decimal('0.2308')),
#  (10811, 'Teatime Chocolate Biscuits', 15, 106.15384395305927, 137.99999713897705, 31.846153185917785, Decimal('0.2308')),
#  (10827, 'Ikura', 15, 357.6923076923077, 465.0, 107.30769230769232, Decimal('0.2308')),
#  (10989, 'Queso Cabrales', 15, 242.3076923076923, 315.0, 72.69230769230771, Decimal('0.2308')),
#  (10811, 'Boston Crab Meat', 30, 424.61537581223706, 551.9999885559082, 127.38461274367114, Decimal('0.2308')),
#  (10691, 'Tarte au sucre', 48, 1820.3076641376201, 2366.3999633789062, 546.0922992412861, Decimal('0.2308')),
#  (10817, 'Côte de Blaye', 30, 6080.7692307692305, 7905.0, 1824.2307692307695, Decimal('0.2308')),
#  (10824, 'Outback Lager', 9, 103.84615384615384, 135.0, 31.15384615384616, Decimal('0.2308')),
#  (10958, "Chef Anton's Gumbo Mix", 20, 328.46154433030347, 427.00000762939453, 98.53846329909106, Decimal('0.2308')),
#  (10703, 'Raclette Courdavault', 35, 1480.7692307692307, 1925.0, 444.2307692307693, Decimal('0.2308')),
#  (10958, "Uncle Bob's Organic Dried Pears", 6, 138.46153846153845, 180.0, 41.53846153846155, Decimal('0.2308')),
#  (10819, 'Rhönbräu Klosterbier', 20, 119.23076923076923, 155.0, 35.769230769230774, Decimal('0.2308')),
#  (10822, 'Outback Lager', 6, 69.23076923076923, 90.0, 20.769230769230774, Decimal('0.2308')),
#  (10822, 'Tarte au sucre', 3, 113.76922900860126, 147.89999771118164, 34.13076870258038, Decimal('0.2308')),
#  (10821, 'Steeleye Stout', 20, 276.9230769230769, 360.0, 83.0769230769231, Decimal('0.2308')),
#  (10691, 'Chai', 30, 415.38461538461536, 540.0, 124.61538461538464, Decimal('0.2308')),
#  (10961, 'Lakkalikööri', 60, 830.7692307692307, 1080.0, 249.23076923076928, Decimal('0.2308')),
#  (10734, 'Lakkalikööri', 20, 276.9230769230769, 360.0, 83.0769230769231, Decimal('0.2308')),
#  (10685, 'Ikura', 20, 476.9230769230769, 620.0, 143.0769230769231, Decimal('0.2308')),
#  (10695, 'Guaraná Fantástica', 20, 69.23076923076923, 90.0, 20.769230769230774, Decimal('0.2308')),
#  (11001, "Uncle Bob's Organic Dried Pears", 60, 1384.6153846153845, 1800.0, 415.3846153846155, Decimal('0.2308')),
#  (10682, 'Rhönbräu Klosterbier', 30, 178.84615384615384, 232.5, 53.65384615384616, Decimal('0.2308')),
#  (10736, 'Louisiana Fiery Hot Pepper Sauce', 40, 647.6922842172476, 841.9999694824219, 194.3076852651743, Decimal('0.2308')),
#  (10736, 'Rhönbräu Klosterbier', 20, 119.23076923076923, 155.0, 35.769230769230774, Decimal('0.2308')),
#  (10678, 'Tourtière', 30, 171.92307252150314, 223.4999942779541, 51.57692175645096, Decimal('0.2308')),
#  (10694, 'Raclette Courdavault', 25, 1057.6923076923076, 1375.0, 317.3076923076924, Decimal('0.2308')),
#  (10933, 'Perth Pasties', 2, 50.461537287785454, 65.5999984741211, 15.13846118633564, Decimal('0.2308')),
#  (10911, 'Chai', 10, 138.46153846153845, 180.0, 41.53846153846155, Decimal('0.2308')),
#  (10964, 'Gudbrandsdalsost', 10, 276.9230769230769, 360.0, 83.0769230769231, Decimal('0.2308')),
#  (10910, 'Maxilaku', 10, 153.84615384615384, 200.0, 46.15384615384616, Decimal('0.2308')),
#  (10674, 'Tunnbröd', 5, 34.61538461538461, 45.0, 10.384615384615387, Decimal('0.2308')),
#  (10965, 'Manjimup Dried Apples', 16, 652.3076923076923, 848.0, 195.69230769230774, Decimal('0.2308')),
#  (10732, 'Lakkalikööri', 20, 276.9230769230769, 360.0, 83.0769230769231, Decimal('0.2308')),
#  (10909, "Uncle Bob's Organic Dried Pears", 12, 276.9230769230769, 360.0, 83.0769230769231, Decimal('0.2308')),
#  (10672, 'Flotemysost', 12, 198.46153846153845, 258.0, 59.53846153846155, Decimal('0.2308')),
#  (10670, 'Spegesild', 60, 553.8461538461538, 720.0, 166.1538461538462, Decimal('0.2308')),
#  (10666, 'Louisiana Fiery Hot Pepper Sauce', 10, 161.9230710543119, 210.49999237060547, 48.57692131629358, Decimal('0.2308')),
#  (10666, 'Thüringer Rostbratwurst', 36, 3428.030794583834, 4456.440032958984, 1028.4092383751504, Decimal('0.2308')),
#  (10904, 'Tarte au sucre', 35, 1327.3076717670147, 1725.4999732971191, 398.1923015301045, Decimal('0.2308')),
#  (10665, 'Lakkalikööri', 10, 138.46153846153845, 180.0, 41.53846153846155, Decimal('0.2308')),
#  (10698, 'Queso Cabrales', 15, 242.3076923076923, 315.0, 72.69230769230771, Decimal('0.2308')),
#  (10729, 'Chai', 50, 692.3076923076923, 900.0, 207.69230769230774, Decimal('0.2308')),
#  (10657, 'Spegesild', 45, 415.38461538461536, 540.0, 124.61538461538464, Decimal('0.2308')),
#  (10742, 'Aniseed Syrup', 20, 153.84615384615384, 200.0, 46.15384615384616, Decimal('0.2308')),
#  (10967, 'Maxilaku', 40, 615.3846153846154, 800.0, 184.61538461538464, Decimal('0.2308')),
#  (10998, "Sirop d'érable", 7, 153.46153846153845, 199.5, 46.03846153846155, Decimal('0.2308')),
#  (10742, 'Camembert Pierrot', 50, 1307.6923076923076, 1700.0, 392.3076923076924, Decimal('0.2308')),
#  (10897, 'Nord-Ost Matjeshering', 36, 716.9538292518029, 932.0399780273438, 215.0861487755409, Decimal('0.2308')),
#  (10968, 'Guaraná Fantástica', 30, 103.84615384615384, 135.0, 31.15384615384616, Decimal('0.2308')),
#  (10973, 'Rhönbräu Klosterbier', 10, 59.61538461538461, 77.5, 17.884615384615387, Decimal('0.2308')),
#  (10930, "Sir Rodney's Scones", 36, 276.9230769230769, 360.0, 83.0769230769231, Decimal('0.2308')),
#  (10895, 'Camembert Pierrot', 100, 2615.3846153846152, 3400.0, 784.6153846153848, Decimal('0.2308')),
#  (10943, 'Spegesild', 15, 138.46153846153845, 180.0, 41.53846153846155, Decimal('0.2308')),
#  (10742, 'Mozzarella di Giovanni', 35, 936.9230563823993, 1217.9999732971191, 281.07691691471985, Decimal('0.2308')),
#  (11069, 'Chartreuse verte', 20, 276.9230769230769, 360.0, 83.0769230769231, Decimal('0.2308')),
#  (10650, 'Tourtière', 30, 171.92307252150314, 223.4999942779541, 51.57692175645096, Decimal('0.2308')),
#  (10648, "Gustaf's Knäckebröd", 15, 242.3076923076923, 315.0, 72.69230769230771, Decimal('0.2308')),
#  (10647, 'Chartreuse verte', 20, 276.9230769230769, 360.0, 83.0769230769231, Decimal('0.2308')),
#  (10647, 'Teatime Chocolate Biscuits', 30, 212.30768790611853, 275.9999942779541, 63.69230637183557, Decimal('0.2308')),
#  (10893, 'Nord-Ost Matjeshering', 35, 697.0384451059194, 906.1499786376953, 209.11153353177588, Decimal('0.2308')),
#  (10745, 'Mozzarella di Giovanni', 7, 187.38461127647986, 243.59999465942383, 56.21538338294397, Decimal('0.2308')),
#  (10893, 'Guaraná Fantástica', 10, 34.61538461538461, 45.0, 10.384615384615387, Decimal('0.2308')),
#  (10746, 'Tarte au sucre', 9, 341.3076870258038, 443.6999931335449, 102.39230610774115, Decimal('0.2308')),
#  (10746, 'Gudbrandsdalsost', 40, 1107.6923076923076, 1440.0, 332.3076923076924, Decimal('0.2308')),
#  (10641, 'Boston Crab Meat', 60, 849.2307516244741, 1103.9999771118164, 254.76922548734228, Decimal('0.2308')),
#  (10975, 'Rhönbräu Klosterbier', 10, 59.61538461538461, 77.5, 17.884615384615387, Decimal('0.2308')),
#  (11010, 'Guaraná Fantástica', 10, 34.61538461538461, 45.0, 10.384615384615387, Decimal('0.2308')),
#  (10997, 'Mascarpone Fabioli', 50, 1230.7692307692307, 1600.0, 369.2307692307693, Decimal('0.2308')),
#  (10747, 'Gorgonzola Telino', 8, 76.92307692307692, 100.0, 23.07692307692308, Decimal('0.2308')),
#  (10717, 'Tourtière', 15, 85.96153626075157, 111.74999713897705, 25.78846087822548, Decimal('0.2308')),
#  (10888, 'Scottish Longbreads', 18, 173.07692307692307, 225.0, 51.923076923076934, Decimal('0.2308')),
#  (10747, 'Gudbrandsdalsost', 30, 830.7692307692307, 1080.0, 249.23076923076928, Decimal('0.2308')),
#  (10630, 'Lakkalikööri', 35, 484.6153846153846, 630.0, 145.38461538461542, Decimal('0.2308')),
#  (10928, 'Lakkalikööri', 5, 69.23076923076923, 90.0, 20.769230769230774, Decimal('0.2308')),
#  (10629, 'Wimmers gute Semmelknödel', 9, 230.19230769230768, 299.25, 69.05769230769232, Decimal('0.2308')),
#  (10628, 'Chai', 25, 346.15384615384613, 450.0, 103.84615384615387, Decimal('0.2308')),
#  (10977, 'Chartreuse verte', 30, 415.38461538461536, 540.0, 124.61538461538464, Decimal('0.2308')),
#  (10885, 'Outback Lager', 30, 346.15384615384613, 450.0, 103.84615384615387, Decimal('0.2308')),
#  (11066, 'Sasquatch Ale', 35, 376.9230769230769, 490.0, 113.0769230769231, Decimal('0.2308')),
#  (11064, 'Scottish Longbreads', 55, 528.8461538461538, 687.5, 158.6538461538462, Decimal('0.2308')),
#  (10716, "Sir Rodney's Scones", 5, 38.46153846153846, 50.0, 11.53846153846154, Decimal('0.2308')),
#  (10621, 'Tunnbröd', 10, 69.23076923076923, 90.0, 20.769230769230774, Decimal('0.2308')),
#  (10620, 'Guaraná Fantástica', 5, 17.307692307692307, 22.5, 5.192307692307693, Decimal('0.2308')),
#  (10614, 'Chartreuse verte', 5, 69.23076923076923, 90.0, 20.769230769230774, Decimal('0.2308')),
#  (10613, 'Rhönbräu Klosterbier', 40, 238.46153846153845, 310.0, 71.53846153846155, Decimal('0.2308')),
#  (10927, 'Lakkalikööri', 20, 276.9230769230769, 360.0, 83.0769230769231, Decimal('0.2308')),
#  (10612, 'Lakkalikööri', 80, 1107.6923076923076, 1440.0, 332.3076923076924, Decimal('0.2308')),
#  (10612, 'Maxilaku', 18, 276.9230769230769, 360.0, 83.0769230769231, Decimal('0.2308')),
#  (10612, 'Inlagd Sill', 55, 803.8461538461538, 1045.0, 241.1538461538462, Decimal('0.2308')),
#  (10879, 'Lakkalikööri', 10, 138.46153846153845, 180.0, 41.53846153846155, Decimal('0.2308')),
#  (10879, 'Louisiana Fiery Hot Pepper Sauce', 10, 161.9230710543119, 210.49999237060547, 48.57692131629358, Decimal('0.2308')),
#  (11059, 'Konbu', 30, 138.46153846153845, 180.0, 41.53846153846155, Decimal('0.2308')),
#  (10609, 'Ikura', 10, 238.46153846153845, 310.0, 71.53846153846155, Decimal('0.2308')),
#  (10979, "Uncle Bob's Organic Dried Pears", 18, 415.38461538461536, 540.0, 124.61538461538464, Decimal('0.2308')),
#  (11057, 'Outback Lager', 3, 34.61538461538461, 45.0, 10.384615384615387, Decimal('0.2308')),
#  (10979, 'Guaraná Fantástica', 80, 276.9230769230769, 360.0, 83.0769230769231, Decimal('0.2308')),
#  (11056, 'Camembert Pierrot', 50, 1307.6923076923076, 1700.0, 392.3076923076924, Decimal('0.2308')),
#  (10749, 'Lakkalikööri', 10, 138.46153846153845, 180.0, 41.53846153846155, Decimal('0.2308')),
#  (10874, 'Ikura', 10, 238.46153846153845, 310.0, 71.53846153846155, Decimal('0.2308')),
#  (10601, 'Raclette Courdavault', 35, 1480.7692307692307, 1925.0, 444.2307692307693, Decimal('0.2308')),
#  (10873, "Sir Rodney's Scones", 20, 153.84615384615384, 200.0, 46.15384615384616, Decimal('0.2308')),
#  (10601, 'Konbu', 60, 276.9230769230769, 360.0, 83.0769230769231, Decimal('0.2308')),
#  (10600, 'Röd Kaviar', 30, 346.15384615384613, 450.0, 103.84615384615387, Decimal('0.2308')),
#  (10598, 'Flotemysost', 9, 148.84615384615384, 193.5, 44.65384615384616, Decimal('0.2308')),
#  (10751, 'Röd Kaviar', 15, 173.07692307692307, 225.0, 51.923076923076934, Decimal('0.2308')),
#  (11055, 'Guaraná Fantástica', 15, 51.92307692307692, 67.5, 15.57692307692308, Decimal('0.2308')),
#  (11054, 'Geitost', 10, 19.23076923076923, 25.0, 5.76923076923077, Decimal('0.2308')),
#  (10590, 'Chai', 20, 276.9230769230769, 360.0, 83.0769230769231, Decimal('0.2308')),
#  (10870, 'Manjimup Dried Apples', 2, 81.53846153846153, 106.0, 24.461538461538467, Decimal('0.2308')),
#  (10587, 'Steeleye Stout', 20, 276.9230769230769, 360.0, 83.0769230769231, Decimal('0.2308')),
#  (10753, 'Longlife Tofu', 5, 38.46153846153846, 50.0, 11.53846153846154, Decimal('0.2308')),
#  (10869, 'Tunnbröd', 50, 346.15384615384613, 450.0, 103.84615384615387, Decimal('0.2308')),
#  (10578, 'Steeleye Stout', 20, 276.9230769230769, 360.0, 83.0769230769231, Decimal('0.2308')),
#  (10869, 'Chai', 40, 553.8461538461538, 720.0, 166.1538461538462, Decimal('0.2308')),
#  (10577, 'Rhönbräu Klosterbier', 20, 119.23076923076923, 155.0, 35.769230769230774, Decimal('0.2308')),
#  (10868, 'Steeleye Stout', 30, 415.38461538461536, 540.0, 124.61538461538464, Decimal('0.2308')),
#  (10577, 'Chartreuse verte', 10, 138.46153846153845, 180.0, 41.53846153846155, Decimal('0.2308')),
#  (10576, 'Chai', 10, 138.46153846153845, 180.0, 41.53846153846155, Decimal('0.2308')),
#  (10575, 'Lakkalikööri', 10, 138.46153846153845, 180.0, 41.53846153846155, Decimal('0.2308')),
#  (10574, 'Wimmers gute Semmelknödel', 6, 153.46153846153845, 199.5, 46.03846153846155, Decimal('0.2308')),
#  (10574, 'Boston Crab Meat', 2, 28.307691720815804, 36.79999923706055, 8.492307516244743, Decimal('0.2308')),
#  (11013, 'Tunnbröd', 10, 69.23076923076923, 90.0, 20.769230769230774, Decimal('0.2308')),
#  (10569, 'Lakkalikööri', 30, 415.38461538461536, 540.0, 124.61538461538464, Decimal('0.2308')),
#  (10568, 'Ikura', 5, 119.23076923076923, 155.0, 35.769230769230774, Decimal('0.2308')),
#  (10566, 'Lakkalikööri', 10, 138.46153846153845, 180.0, 41.53846153846155, Decimal('0.2308')),
#  (10861, 'Tarte au sucre', 3, 113.76922900860126, 147.89999771118164, 34.13076870258038, Decimal('0.2308')),
#  (10946, 'Guaraná Fantástica', 25, 86.53846153846153, 112.5, 25.961538461538467, Decimal('0.2308')),
#  (10861, "Sir Rodney's Scones", 40, 307.6923076923077, 400.0, 92.30769230769232, Decimal('0.2308')),
#  (11044, 'Tarte au sucre', 12, 455.07691603440503, 591.5999908447266, 136.52307481032153, Decimal('0.2308')),
#  (10998, 'Longlife Tofu', 20, 153.84615384615384, 200.0, 46.15384615384616, Decimal('0.2308')),
#  (10860, 'Lakkalikööri', 20, 276.9230769230769, 360.0, 83.0769230769231, Decimal('0.2308')),
#  (11013, 'Scottish Longbreads', 2, 19.23076923076923, 25.0, 5.76923076923077, Decimal('0.2308')),
#  (10563, 'Filo Mix', 70, 376.9230769230769, 490.0, 113.0769230769231, Decimal('0.2308')),
#  (10981, 'Côte de Blaye', 60, 12161.538461538461, 15810.0, 3648.461538461539, Decimal('0.2308')),
#  (10757, 'Wimmers gute Semmelknödel', 24, 613.8461538461538, 798.0, 184.1538461538462, Decimal('0.2308')),
#  (10561, 'Manjimup Dried Apples', 50, 2038.4615384615383, 2650.0, 611.5384615384617, Decimal('0.2308')),
#  (10713, 'Rogede sild', 110, 803.8461538461538, 1045.0, 241.1538461538462, Decimal('0.2308')),
#  (10558, 'Röd Kaviar', 3, 34.61538461538461, 45.0, 10.384615384615387, Decimal('0.2308')),
#  (10558, 'Perth Pasties', 18, 454.1538355900691, 590.3999862670898, 136.24615067702075, Decimal('0.2308')),
#  (10557, 'Rhönbräu Klosterbier', 20, 119.23076923076923, 155.0, 35.769230769230774, Decimal('0.2308')),
#  (10557, 'Wimmers gute Semmelknödel', 30, 767.3076923076923, 997.5, 230.19230769230774, Decimal('0.2308')),
#  (11040, "Sir Rodney's Scones", 20, 153.84615384615384, 200.0, 46.15384615384616, Decimal('0.2308')),
# ...
#  (10673, 'Ipoh Coffee', 6, 212.30769230769232, 276.0, 63.69230769230768, Decimal('0.2308')),
#  (10952, 'Rössle Sauerkraut', 2, 70.15384380634015, 91.19999694824219, 21.04615314190204, Decimal('0.2308')),
#  (10780, 'Outback Lager', 35, 403.84615384615387, 525.0, 121.15384615384613, Decimal('0.2308')),
#  (10733, 'Rössle Sauerkraut', 20, 701.5384380634015, 911.9999694824219, 210.4615314190204, Decimal('0.2308')),
#  (10835, 'Raclette Courdavault', 15, 634.6153846153846, 825.0, 190.38461538461536, Decimal('0.2308')),
#  (10556, 'Mozzarella di Giovanni', 24, 642.4615243765024, 835.1999816894531, 192.7384573129507, Decimal('0.2308')),
#  (10856, 'Chang', 20, 292.3076923076923, 380.0, 87.69230769230768, Decimal('0.2308')),
#  (10691, 'Ipoh Coffee', 40, 1415.3846153846155, 1840.0, 424.6153846153845, Decimal('0.2308')),
#  (11043, 'Queso Cabrales', 10, 161.53846153846155, 210.0, 48.46153846153845, Decimal('0.2308')),
#  (10792, 'Chang', 10, 146.15384615384616, 190.0, 43.84615384615384, Decimal('0.2308')),
#  (10670, 'Rhönbräu Klosterbier', 25, 149.03846153846155, 193.75, 44.71153846153845, Decimal('0.2308')),
#  (11013, 'Rogede sild', 20, 146.15384615384616, 190.0, 43.84615384615384, Decimal('0.2308')),
#  (10797, 'Queso Cabrales', 20, 323.0769230769231, 420.0, 96.9230769230769, Decimal('0.2308')),
#  (10907, 'Rhönbräu Klosterbier', 14, 83.46153846153847, 108.5, 25.038461538461533, Decimal('0.2308')),
#  (10804, 'Rössle Sauerkraut', 24, 841.8461256760818, 1094.3999633789062, 252.55383770282447, Decimal('0.2308')),
#  (11018, 'Queso Manchego La Pastora', 20, 584.6153846153846, 760.0, 175.38461538461536, Decimal('0.2308')),
#  (10829, 'Chang', 10, 146.15384615384616, 190.0, 43.84615384615384, Decimal('0.2308')),
#  (11018, 'Gnocchi di nonna Alice', 5, 146.15384615384616, 190.0, 43.84615384615384, Decimal('0.2308')),
#  (10703, 'Röd Kaviar', 35, 403.84615384615387, 525.0, 121.15384615384613, Decimal('0.2308')),
#  (10575, 'Mozzarella di Giovanni', 30, 803.076905470628, 1043.9999771118164, 240.92307164118836, Decimal('0.2308')),
#  (10703, 'Chang', 5, 73.07692307692308, 95.0, 21.92307692307692, Decimal('0.2308')),
#  (10869, 'Queso Cabrales', 10, 161.53846153846155, 210.0, 48.46153846153845, Decimal('0.2308')),
#  (10819, 'Ipoh Coffee', 7, 247.6923076923077, 322.0, 74.30769230769229, Decimal('0.2308')),
#  (10906, "Sirop d'érable", 15, 328.84615384615387, 427.5, 98.65384615384613, Decimal('0.2308')),
#  (10987, 'Ipoh Coffee', 6, 212.30769230769232, 276.0, 63.69230769230768, Decimal('0.2308')),
#  (11073, 'Queso Cabrales', 10, 161.53846153846155, 210.0, 48.46153846153845, Decimal('0.2308')),
#  (10937, 'Rössle Sauerkraut', 8, 280.6153752253606, 364.79998779296875, 84.18461256760816, Decimal('0.2308')),
#  (10657, 'Zaanse koeken', 10, 73.07692307692308, 95.0, 21.92307692307692, Decimal('0.2308')),
#  (10726, "Chef Anton's Cajun Seasoning", 25, 423.0769230769231, 550.0, 126.9230769230769, Decimal('0.2308')),
#  (11005, 'Raclette Courdavault', 10, 423.0769230769231, 550.0, 126.9230769230769, Decimal('0.2308')),
#  (10984, 'Inlagd Sill', 40, 584.6153846153846, 760.0, 175.38461538461536, Decimal('0.2308')),
#  (10649, 'Mozzarella di Giovanni', 15, 401.538452735314, 521.9999885559082, 120.46153582059418, Decimal('0.2308')),
#  (10873, 'Rössle Sauerkraut', 3, 105.23076570951022, 136.79999542236328, 31.56922971285306, Decimal('0.2308')),
#  (10649, 'Rössle Sauerkraut', 20, 701.5384380634015, 911.9999694824219, 210.4615314190204, Decimal('0.2308')),
#  (10718, 'Inlagd Sill', 40, 584.6153846153846, 760.0, 175.38461538461536, Decimal('0.2308')),
#  (10893, 'Inlagd Sill', 20, 292.3076923076923, 380.0, 87.69230769230768, Decimal('0.2308')),
#  (10976, 'Rössle Sauerkraut', 20, 701.5384380634015, 911.9999694824219, 210.4615314190204, Decimal('0.2308')),
#  (10607, 'Mozzarella di Giovanni', 12, 321.2307621882512, 417.59999084472656, 96.36922865647534, Decimal('0.2308')),
#  (10644, 'Ipoh Coffee', 20, 707.6923076923077, 920.0, 212.30769230769226, Decimal('0.2308')),
#  (10611, 'Chang', 10, 146.15384615384616, 190.0, 43.84615384615384, Decimal('0.2308')),
#  (10718, 'Queso Manchego La Pastora', 36, 1052.3076923076924, 1368.0, 315.6923076923076, Decimal('0.2308')),
#  (10638, 'Mozzarella di Giovanni', 60, 1606.153810941256, 2087.999954223633, 481.8461432823767, Decimal('0.2308')),
#  (10618, 'Gnocchi di nonna Alice', 20, 584.6153846153846, 760.0, 175.38461538461536, Decimal('0.2308')),
#  (10619, "Gustaf's Knäckebröd", 40, 646.1538461538462, 840.0, 193.8461538461538, Decimal('0.2308')),
#  (10638, 'Rogede sild', 20, 146.15384615384616, 190.0, 43.84615384615384, Decimal('0.2308')),
#  (10979, 'Queso Manchego La Pastora', 20, 584.6153846153846, 760.0, 175.38461538461536, Decimal('0.2308')),
#  (10622, 'Chang', 20, 292.3076923076923, 380.0, 87.69230769230768, Decimal('0.2308')),
#  (10637, 'Queso Cabrales', 10, 161.53846153846155, 210.0, 48.46153846153845, Decimal('0.2308')),
#  (10928, 'Zaanse koeken', 5, 36.53846153846154, 47.5, 10.96153846153846, Decimal('0.2308')),
#  (10636, "Chef Anton's Cajun Seasoning", 25, 423.0769230769231, 550.0, 126.9230769230769, Decimal('0.2308')),
#  (10635, "Gustaf's Knäckebröd", 40, 646.1538461538462, 840.0, 193.8461538461538, Decimal('0.2308')),
#  (10624, 'Rössle Sauerkraut', 10, 350.76921903170074, 455.99998474121094, 105.2307657095102, Decimal('0.2308')),
#  (11032, 'Raclette Courdavault', 30, 1269.2307692307693, 1650.0, 380.7692307692307, Decimal('0.2308')),
#  (10726, 'Queso Cabrales', 5, 80.76923076923077, 105.0, 24.230769230769226, Decimal('0.2308')),
#  (10946, 'Ikura', 25, 596.1538461538462, 775.0, 178.8461538461538, Decimal('0.2308')),
#  (10885, 'Chang', 20, 292.3076923076923, 380.0, 87.69230769230768, Decimal('0.2308')),
#  (10634, "Uncle Bob's Organic Dried Pears", 35, 807.6923076923077, 1050.0, 242.30769230769226, Decimal('0.2308')),
#  (10889, 'Queso Cabrales', 40, 646.1538461538462, 840.0, 193.8461538461538, Decimal('0.2308')),
#  (10846, "Chef Anton's Cajun Seasoning", 21, 355.3846153846154, 462.0, 106.61538461538458, Decimal('0.2308')),
#  (10929, 'Rhönbräu Klosterbier', 49, 292.11538461538464, 379.75, 87.63461538461536, Decimal('0.2308')),
#  (10514, 'Rössle Sauerkraut', 35, 1227.6922666109526, 1595.9999465942383, 368.30767998328565, Decimal('0.2308')),
#  (10704, "Chef Anton's Cajun Seasoning", 6, 101.53846153846155, 132.0, 30.461538461538453, Decimal('0.2308')),
#  (11023, 'Ipoh Coffee', 30, 1061.5384615384617, 1380.0, 318.46153846153834, Decimal('0.2308')),
#  (10924, 'Rhönbräu Klosterbier', 6, 35.769230769230774, 46.5, 10.730769230769226, Decimal('0.2308')),
#  (10775, 'Ikura', 6, 143.0769230769231, 186.0, 42.923076923076906, Decimal('0.2308')),
#  (10524, 'Ipoh Coffee', 60, 2123.0769230769233, 2760.0, 636.9230769230767, Decimal('0.2308')),
#  (10865, 'Côte de Blaye', 60, 12161.538461538461, 15809.949999999255, 3648.411538460794, Decimal('0.2308')),
#  (10816, 'Côte de Blaye', 30, 6080.7692307692305, 7904.949999999255, 1824.1807692300245, Decimal('0.2308')),
#  (10776, 'Manjimup Dried Apples', 120, 4892.307692307692, 6359.949999999255, 1467.6423076915626, Decimal('0.2308')),
#  (10953, "Sir Rodney's Marmalade", 50, 3115.3846153846152, 4049.949999999255, 934.5653846146397, Decimal('0.2308')),
#  (10616, 'Côte de Blaye', 15, 3040.3846153846152, 3952.449999999255, 912.0653846146397, Decimal('0.2308')),
#  (11008, 'Rössle Sauerkraut', 70, 2455.3845332219053, 3191.9498931877315, 736.5653599658262, Decimal('0.2308')),
#  (10787, 'Thüringer Rostbratwurst', 20, 1904.4615525465745, 2475.750018309802, 571.2884657632274, Decimal('0.2308')),
#  (10605, 'Camembert Pierrot', 70, 1830.7692307692307, 2379.949999999255, 549.1807692300242, Decimal('0.2308')),
#  (10851, 'Raclette Courdavault', 42, 1776.923076923077, 2309.949999999255, 533.026923076178, Decimal('0.2308')),
#  (10637, 'Gnocchi di nonna Alice', 60, 1753.8461538461538, 2279.949999999255, 526.1038461531011, Decimal('0.2308')),
#  (10570, 'Gnocchi di nonna Alice', 60, 1753.8461538461538, 2279.949999999255, 526.1038461531011, Decimal('0.2308')),
#  (10892, 'Raclette Courdavault', 40, 1692.3076923076924, 2199.949999999255, 507.64230769156256, Decimal('0.2308')),
#  (10672, 'Côte de Blaye', 15, 3040.3846153846152, 3952.39999999851, 912.0153846138946, Decimal('0.2307')),
#  (10658, 'Camembert Pierrot', 55, 1438.4615384615383, 1869.949999999255, 431.4884615377166, Decimal('0.2307')),
#  (10894, 'Gudbrandsdalsost', 50, 1384.6153846153845, 1799.949999999255, 415.3346153838704, Decimal('0.2307')),
#  (10791, 'Thüringer Rostbratwurst', 14, 1333.123086782602, 1733.0100128166378, 399.8869260340357, Decimal('0.2307')),
#  (10878, "Sir Rodney's Marmalade", 20, 1246.1538461538462, 1619.949999999255, 373.79615384540875, Decimal('0.2307')),
#  (10731, 'Manjimup Dried Apples', 30, 1223.076923076923, 1589.949999999255, 366.87307692233185, Decimal('0.2307')),
#  (11064, 'Alice Mutton', 77, 2310.0, 3002.89999999851, 692.8999999985099, Decimal('0.2307')),
#  (11030, 'Thüringer Rostbratwurst', 60, 5713.384657639724, 7427.150054931641, 1713.765397291917, Decimal('0.2307')),
#  (10912, 'Thüringer Rostbratwurst', 60, 5713.384657639724, 7427.150054931641, 1713.765397291917, Decimal('0.2307')),
#  (10698, 'Thüringer Rostbratwurst', 12, 1142.6769315279446, 1485.430010985583, 342.7530794576385, Decimal('0.2307')),
#  (10865, 'Chartreuse verte', 80, 1107.6923076923076, 1439.949999999255, 332.2576923069473, Decimal('0.2307')),
#  (10698, 'Louisiana Fiery Hot Pepper Sauce', 65, 1052.4999618530273, 1368.1999504081905, 315.69998855516315, Decimal('0.2307')),
#  (10688, 'Rössle Sauerkraut', 60, 2104.6153141902046, 2735.8999084457755, 631.2845942555709, Decimal('0.2307')),
#  (10633, 'Tarte au sucre', 80, 3033.8461068960332, 3943.8499389588833, 910.00383206285, Decimal('0.2307')),
#  (11012, 'Flotemysost', 60, 992.3076923076922, 1289.949999999255, 297.6423076915628, Decimal('0.2307')),
#  (10658, 'Boston Crab Meat', 70, 990.7692102285531, 1287.949973296374, 297.180763067821, Decimal('0.2307')),
#  (11008, 'Sasquatch Ale', 90, 969.2307692307692, 1259.949999999255, 290.7192307684858, Decimal('0.2307')),
#  (10871, "Grandma's Boysenberry Spread", 50, 961.5384615384615, 1249.949999999255, 288.4115384607934, Decimal('0.2307')),
#  (10993, 'Thüringer Rostbratwurst', 50, 4761.153881366436, 6189.250045776367, 1428.0961644099316, Decimal('0.2307')),
#  (11012, 'Camembert Pierrot', 36, 941.5384615384615, 1223.949999999255, 282.4115384607934, Decimal('0.2307')),
#  (10764, 'Chartreuse verte', 130, 1799.9999999999998, 2339.89999999851, 539.8999999985101, Decimal('0.2307')),
#  (11033, 'Perth Pasties', 70, 1766.153805072491, 2295.899946592748, 529.7461415202572, Decimal('0.2307')),
#  (11030, 'Raclette Courdavault', 100, 4230.7692307692305, 5499.75, 1268.9807692307695, Decimal('0.2307')),
#  (10605, 'Raclette Courdavault', 20, 846.1538461538462, 1099.949999999255, 253.79615384540875, Decimal('0.2307')),
#  (10533, "Chef Anton's Cajun Seasoning", 50, 846.1538461538462, 1099.949999999255, 253.79615384540875, Decimal('0.2307')),
#  (10823, 'Raclette Courdavault', 40, 1692.3076923076924, 2199.89999999851, 507.5923076908175, Decimal('0.2307')),
#  (10663, 'Manjimup Dried Apples', 20, 815.3846153846154, 1059.949999999255, 244.56538461463958, Decimal('0.2307')),
#  (10854, 'Ikura', 100, 2384.6153846153848, 3099.8499999940395, 715.2346153786548, Decimal('0.2307')),
#  (10834, 'Thüringer Rostbratwurst', 8, 761.7846210186298, 990.2700073234737, 228.48538630484393, Decimal('0.2307')),
#  (10994, 'Raclette Courdavault', 18, 761.5384615384615, 989.9499999992549, 228.4115384607934, Decimal('0.2307')),
#  (10554, 'Tarte au sucre', 20, 758.4615267240083, 985.9499847404659, 227.48845801645757, Decimal('0.2307')),
#  (10872, 'Tarte au sucre', 20, 758.4615267240083, 985.9499847404659, 227.48845801645757, Decimal('0.2307')),
#  (10816, 'Tarte au sucre', 20, 758.4615267240083, 985.9499847404659, 227.48845801645757, Decimal('0.2307')),
#  (10988, 'Tarte au sucre', 40, 1516.9230534480166, 1971.8999694809318, 454.97691603291514, Decimal('0.2307')),
#  (10721, 'Gula Malacca', 50, 748.0769524207482, 972.4500381462276, 224.37308572547943, Decimal('0.2307')),
#  (10687, 'Mishi Kobe Niku', 50, 3730.7692307692305, 4849.75, 1118.9807692307695, Decimal('0.2307')),
#  (10515, 'Camembert Pierrot', 84, 2196.9230769230767, 2855.8499999940395, 658.9269230709629, Decimal('0.2307')),
#  (10894, 'Rhönbräu Klosterbier', 120, 715.3846153846154, 929.9499999992549, 214.56538461463958, Decimal('0.2307')),
#  (10658, 'Original Frankfurter grüne Soße', 70, 700.0, 909.9499999992549, 209.94999999925494, Decimal('0.2307')),
#  (10717, 'Gudbrandsdalsost', 25, 692.3076923076923, 899.9499999992549, 207.64230769156268, Decimal('0.2307')),
#  (10549, 'Manjimup Dried Apples', 48, 1956.9230769230767, 2543.8499999940395, 586.9269230709629, Decimal('0.2307')),
#  (10765, 'Louisiana Fiery Hot Pepper Sauce', 80, 1295.3845684344951, 1683.8999389633536, 388.5153705288585, Decimal('0.2307')),
#  (10803, 'Raclette Courdavault', 15, 634.6153846153846, 824.9499999992549, 190.3346153838703, Decimal('0.2307')),
#  (10650, 'Perth Pasties', 25, 630.7692160973181, 819.9499809257686, 189.1807648284505, Decimal('0.2307')),
#  (10884, 'Gnocchi di nonna Alice', 21, 613.8461538461538, 797.9499999992549, 184.10384615310113, Decimal('0.2307')),
#  (10999, 'Manjimup Dried Apples', 15, 611.5384615384615, 794.9499999992549, 183.4115384607934, Decimal('0.2307')),
#  (10516, 'Carnarvon Tigers', 25, 1201.923076923077, 1562.3999999985099, 360.476923075433, Decimal('0.2307')),
#  (10590, 'Original Frankfurter grüne Soße', 60, 600.0, 779.9499999992549, 179.94999999925494, Decimal('0.2307')),
#  (10727, 'Alice Mutton', 20, 600.0, 779.9499999992549, 179.94999999925494, Decimal('0.2307')),
#  (10701, 'Raclette Courdavault', 42, 1776.923076923077, 2309.8499999940395, 532.9269230709626, Decimal('0.2307')),
#  (11046, 'Queso Manchego La Pastora', 20, 584.6153846153846, 759.9499999992549, 175.3346153838703, Decimal('0.2307')),
#  (10812, 'Mozzarella di Giovanni', 40, 1070.7692072941707, 1391.8999694809318, 321.1307621867611, Decimal('0.2307')),
#  (10595, "Sirop d'érable", 120, 2630.769230769231, 3419.75, 788.980769230769, Decimal('0.2307')),
#  (10924, 'Rössle Sauerkraut', 30, 1052.3076570951023, 1367.8999542221427, 315.5922971270404, Decimal('0.2307')),
#  (11033, 'Gudbrandsdalsost', 36, 996.9230769230768, 1295.8999999985099, 298.9769230754331, Decimal('0.2307')),
#  (10580, 'Louisiana Fiery Hot Pepper Sauce', 30, 485.7692131629357, 631.4499771110713, 145.68076394813562, Decimal('0.2307')),
#  (10990, "Sirop d'érable", 66, 1446.923076923077, 1880.8499999940395, 433.92692307096263, Decimal('0.2307')),
#  (10588, 'Carnarvon Tigers', 40, 1923.0769230769229, 2499.7999999970198, 576.7230769200969, Decimal('0.2307')),
#  (10953, 'Gorgonzola Telino', 50, 480.7692307692308, 624.9499999992549, 144.18076923002417, Decimal('0.2307')),
#  (10584, 'Gorgonzola Telino', 50, 480.7692307692308, 624.9499999992549, 144.18076923002417, Decimal('0.2307')),
#  (10871, 'Alice Mutton', 16, 480.0, 623.9499999992549, 143.94999999925494, Decimal('0.2307')),
#  (10564, 'Alice Mutton', 16, 480.0, 623.9499999992549, 143.94999999925494, Decimal('0.2307')),
#  (10523, "Sir Rodney's Marmalade", 15, 934.6153846153846, 1214.8999999985099, 280.28461538312524, Decimal('0.2307')),
#  (10564, 'Pâté chinois', 25, 461.5384615384615, 599.9499999992549, 138.41153846079345, Decimal('0.2307')),
#  (10659, 'Outback Lager', 40, 461.53846153846155, 599.9499999992549, 138.4115384607934, Decimal('0.2307')),
#  (10908, "Uncle Bob's Organic Dried Pears", 20, 461.53846153846155, 599.9499999992549, 138.4115384607934, Decimal('0.2307')),
#  (10632, 'Chang', 30, 438.46153846153845, 569.9499999992549, 131.4884615377165, Decimal('0.2307')),
#  (10985, 'Mascarpone Fabioli', 35, 861.5384615384614, 1119.8999999985099, 258.36153846004845, Decimal('0.2307')),
#  (10663, 'Boston Crab Meat', 30, 424.61537581223706, 551.9499885551631, 127.33461274292608, Decimal('0.2307')),
#  (11068, 'Ipoh Coffee', 36, 1273.8461538461538, 1655.8499999940395, 382.0038461478857, Decimal('0.2307')),
#  (10727, 'Raclette Courdavault', 10, 423.0769230769231, 549.9499999992549, 126.87307692233185, Decimal('0.2307')),
#  ...]

# %% [markdown]
# ### Profit Margin Breakdown:
#
# - **5-10% (Low Margin)**: Low margins indicate tight profitability, often requiring high volume to stay afloat. Vulnerable to cost fluctuations and market changes, making it hard to sustain long-term.
#
# - **15-20% (Healthy Margin)**: A solid range that suggests effective cost control and stable profitability. It provides enough flexibility for growth and can weather minor market changes.
#
# - **30%+ (Amazing Margin)**: Exceptional profitability, typically from strong brand value or unique products. It offers significant financial stability, flexibility for reinvestment, and a competitive edge.

# %% [markdown]
# ### Analyze Sales Data to Discover Top Employees and Underperformers

# %%
# %%sql
# -- # Use a CTE (common table expression) to calculate the total sales for each employee
# WITH
# employee_performance AS (
#   SELECT e.employee_id, CONCAT(e.first_name, ' ', e.last_name) AS full_name, SUM((od.unit_price * od.quantity) - od.discount) AS total_revenue
#     FROM employees e
#     JOIN orders o ON e.employee_id = o.employee_id
#     JOIN order_details od ON o.order_id = od.order_id
#    GROUP BY e.employee_id, full_name
#    ORDER BY total_revenue DESC
# )
#
# SELECT *, RANK() OVER(ORDER BY total_revenue DESC) as revenue_rank
#   FROM employee_performance
# Out:
#  * postgresql://postgres@localhost:5432/northwind
# 9 rows affected.
# [(4, 'Margaret Peacock', 250161.70025263727, 1),
#  (3, 'Janet Leverling', 213035.34947973862, 2),
#  (1, 'Nancy Davolio', 202126.72030832618, 3),
#  (2, 'Andrew Fuller', 177738.7104764022, 4),
#  (7, 'Robert King', 141283.04010257125, 5),
#  (8, 'Laura Callahan', 133286.43006531894, 6),
#  (9, 'Anne Dodsworth', 82956.6998177059, 7),
#  (6, 'Michael Suyama', 78188.94993348792, 8),
#  (5, 'Steven Buchanan', 75559.9500032328, 9)]

# %% [markdown]
# ## Calculate Running Total to Analyze Monthly Sales Trends
# Now that we've identified the top performers, management is keen on gaining a more macro-level perspective, specifically around the company's overall sales performance over time. They're looking to visualize the progress of the sales and identify trends that might shape the company's future strategies.
#
# This visual will provide the management team with a clear depiction of sales trends and help identify periods of high or low sales activity.

# %%
# %%sql
# -- # Calculate the running total of sales by month
# SELECT DATE_TRUNC('month', o.order_date) AS month, SUM((od.unit_price * od.quantity) - od.discount) AS revenue
#   FROM orders o
#   JOIN order_details AS od ON o.order_id = od.order_id
#  GROUP BY month
#  ORDER BY month
# Out:
#  * postgresql://postgres@localhost:5432/northwind
# 23 rows affected.
# [(datetime.datetime(1996, 7, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 30188.400194395334),
#  (datetime.datetime(1996, 8, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 26606.700082555413),
#  (datetime.datetime(1996, 9, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 27634.600144468248),
#  (datetime.datetime(1996, 10, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 41198.80002650991),
#  (datetime.datetime(1996, 11, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=57600))), 49701.10030082986),
#  (datetime.datetime(1996, 12, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=57600))), 50947.400600831956),
#  (datetime.datetime(1997, 1, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=57600))), 66687.25026476383),
#  (datetime.datetime(1997, 2, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=57600))), 41201.65001020953),
#  (datetime.datetime(1997, 3, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=57600))), 39976.25013163313),
#  (datetime.datetime(1997, 4, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=57600))), 55695.23995159939),
#  (datetime.datetime(1997, 5, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 56818.64989671111),
#  (datetime.datetime(1997, 6, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 39083.7998807095),
#  (datetime.datetime(1997, 7, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 55459.930070813745),
#  (datetime.datetime(1997, 8, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 49976.83972200006),
#  (datetime.datetime(1997, 9, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 59727.219949837774),
#  (datetime.datetime(1997, 10, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 70322.29981015623),
#  (datetime.datetime(1997, 11, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=57600))), 45909.05979455635),
#  (datetime.datetime(1997, 12, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=57600))), 77467.76000298932),
#  (datetime.datetime(1998, 1, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=57600))), 100845.31980460882),
#  (datetime.datetime(1998, 2, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=57600))), 104556.79993679747),
#  (datetime.datetime(1998, 3, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=57600))), 109816.50005879626),
#  (datetime.datetime(1998, 4, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=57600))), 134621.0598381944),
#  (datetime.datetime(1998, 5, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 19894.919965453446)]

# %% [markdown]
# ## Calculate the Percentage Change in Monthly Sales
#
# Management would like to analyze the month-over-month sales growth rate. Understanding the rate at which sales are increasing or decreasing from month to month will help the management team identify significant trends.

# %%
# %%sql
# -- # Create a CTE that calculates the total sales for each month
# WITH
# monthly_sales AS (
# SELECT DATE_TRUNC('month', o.order_date) AS month, SUM((od.unit_price * od.quantity) - od.discount) AS revenue
#   FROM orders o
#   JOIN order_details AS od ON o.order_id = od.order_id
#  GROUP BY month
#  ORDER BY month
# ),
#
# monthly_sales_lagged AS (
# SELECT *, LAG(revenue, 1) OVER(ORDER BY month) AS previous_month
#   FROM monthly_sales
# )
#
# SELECT *, ROUND(CAST((previous_month / revenue) - 1 AS NUMERIC), 2) AS percent_change
#   FROM monthly_sales_lagged
# Out:
#  * postgresql://postgres@localhost:5432/northwind
# 23 rows affected.
# [(datetime.datetime(1996, 7, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 30188.400194395334, None, None),
#  (datetime.datetime(1996, 8, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 26606.700082555413, 30188.400194395334, Decimal('0.13')),
#  (datetime.datetime(1996, 9, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 27634.600144468248, 26606.700082555413, Decimal('-0.04')),
#  (datetime.datetime(1996, 10, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 41198.80002650991, 27634.600144468248, Decimal('-0.33')),
#  (datetime.datetime(1996, 11, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=57600))), 49701.10030082986, 41198.80002650991, Decimal('-0.17')),
#  (datetime.datetime(1996, 12, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=57600))), 50947.400600831956, 49701.10030082986, Decimal('-0.02')),
#  (datetime.datetime(1997, 1, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=57600))), 66687.25026476383, 50947.400600831956, Decimal('-0.24')),
#  (datetime.datetime(1997, 2, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=57600))), 41201.65001020953, 66687.25026476383, Decimal('0.62')),
#  (datetime.datetime(1997, 3, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=57600))), 39976.25013163313, 41201.65001020953, Decimal('0.03')),
#  (datetime.datetime(1997, 4, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=57600))), 55695.23995159939, 39976.25013163313, Decimal('-0.28')),
#  (datetime.datetime(1997, 5, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 56818.64989671111, 55695.23995159939, Decimal('-0.02')),
#  (datetime.datetime(1997, 6, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 39083.7998807095, 56818.64989671111, Decimal('0.45')),
#  (datetime.datetime(1997, 7, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 55459.930070813745, 39083.7998807095, Decimal('-0.30')),
#  (datetime.datetime(1997, 8, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 49976.83972200006, 55459.930070813745, Decimal('0.11')),
#  (datetime.datetime(1997, 9, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 59727.219949837774, 49976.83972200006, Decimal('-0.16')),
#  (datetime.datetime(1997, 10, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 70322.29981015623, 59727.219949837774, Decimal('-0.15')),
#  (datetime.datetime(1997, 11, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=57600))), 45909.05979455635, 70322.29981015623, Decimal('0.53')),
#  (datetime.datetime(1997, 12, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=57600))), 77467.76000298932, 45909.05979455635, Decimal('-0.41')),
#  (datetime.datetime(1998, 1, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=57600))), 100845.31980460882, 77467.76000298932, Decimal('-0.23')),
#  (datetime.datetime(1998, 2, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=57600))), 104556.79993679747, 100845.31980460882, Decimal('-0.04')),
#  (datetime.datetime(1998, 3, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=57600))), 109816.50005879626, 104556.79993679747, Decimal('-0.05')),
#  (datetime.datetime(1998, 4, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=57600))), 134621.0598381944, 109816.50005879626, Decimal('-0.18')),
#  (datetime.datetime(1998, 5, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=61200))), 19894.919965453446, 134621.0598381944, Decimal('5.77'))]

# %% [markdown]
# # Conclusion
#
# This SQL analysis has provided key insights into Northwind Traders' performance, identifying opportunities to optimize pricing, inventory, marketing, and sales strategies. By examining profit margins, product lifecycles, employee performance, and customer behavior, we’ve equipped the company with data-driven insights to drive profitability and strengthen its competitive edge.
